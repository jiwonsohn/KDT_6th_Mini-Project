# %%
# 자연어 처리 관련 모듈 ------------------------------------------------------------------------
import re
import numpy as np
import pandas as pd
import torch
from collections import Counter
from torch.utils.data import DataLoader, TensorDataset
from konlpy.tag import Okt, Komoran, Kkma


# 시각화 관련 모듈 -----------------------------------------------------------------------------
import matplotlib.pyplot as plt

# %%
tokenizer = Okt()

# %%
rawDF = pd.read_csv('../pronunciation_standard.txt', sep='\t')
rawDF.head(5)
# Out:
#                                    pronunciation  \
# 0             오랫동안 한 동네에서 살았던 할무닌데 도라가주씨 매매 아프네요
# 1             혈압약은 시간을 맞춰 챙겨 드셔야지 안 그러면 효과가 없습니다
# 2    집에 돌아와 보이꺼네 문이 열려 있고 뼈다지가 열어둔 돈 전부 없어지던 어이떼
# 3  아들 오늘 중요한 시험 보니까네 이 생서 하고 사가꼬 묵고 힘내서 시험 잘 바래이
# 4         옛날부터 조상꿈이나 돼지꿈 꾸만 집에 돈 많이 들어온다고 좋아 해찌로
#
#                                      standard
# 0        오랫동안 한 동네에서 살았던 할머니인데 돌아가겨서 마음이 아프네요
# 1          혈압약은 시간을 맞춰 챙겨 드셔야지 안 그러면 효과가 없습니다
# 2   집에 돌아와 보니까 문이 열려 있고 서랍이 열어둔 돈 전부 없어지던 어이떼
# 3  아들 오늘 중요한 시험 보니까 이 생 엿 하고 사서 먹고 힘내서 시험 잘 봐
# 4       옛날부터 조상꿈이나 돼지꿈 꾸면 집에 돈 많이 들어온다고 좋아 했죠

# %%
max_src_len = max( [len(line) for line in rawDF.pronunciation])
print(max_src_len)
# Out:
# 70

# %%
def cleanTxt(sent):
	# 한글 공백 제외 삭제
	sent = re.sub(r"[^가-힣\s]", "", sent)
	return sent

# %%
def load_preprocessed_data(tokenizer):
    encoder_input, decoder_input, decoder_target = [], [], []

    with open("../pronunciation_standard.txt", "r") as lines:
        # print(lines)											# <_io.TextIOWrapper name='../dialect_standard.txt' mode='r' encoding='UTF-8'>
        for i, line in enumerate(lines):
            
            # source 데이터와 target 데이터 분리
            if not i: continue									# header 라인 패스
            elif len(line.strip().split('\t'))==2:
                
                # print(line.strip().split('\t'))					# ['혈압약은 시간을', '혈압약은 시간을']
                
				# 표준어 	방언
                src_line, tar_line = line.strip().split('\t')[1], line.strip().split('\t')[0]
                # print(src_line)
                # print(tar_line)
	
				# source 데이터 전처리
                # print(cleanTxt(src_line))
                src_line = [w for w in tokenizer.morphs(cleanTxt(src_line))]
                # break

				# target 데이터 전처리
                tar_line = tokenizer.morphs(cleanTxt(tar_line))
                tar_line_in = [w for w in (["<sos>"] + tar_line)]
                tar_line_out = [w for w in (tar_line + ["<eos>"])]

                encoder_input.append(src_line)
                decoder_input.append(tar_line_in)
                decoder_target.append(tar_line_out)
                

            # if i == len(lines) - 1:
            #     break

    return encoder_input, decoder_input, decoder_target

# %%
tokenizer.morphs( cleanTxt("오랫동안 한 동네에서 살았던 할머니이제 도주식하면 매매 아프네요")) + ["<eos>"]

# %%
# tmp = "올해는
#  배치 농사를 망우가 짐장을 할라믄 배치를 좀 사와가 담구야 데겠네"	"올해는
#  배추 농사를 망쳐서 김장을 하려면 배추를 좀 사와서 담궈야 되겠네"

# %%
sents_std_in, sents_di_in, sents_di_out = load_preprocessed_data(tokenizer)
print('인코더의 입력 :',sents_std_in[:5])
print('디코더의 입력 :',sents_di_in[:5])
print('디코더의 레이블 :',sents_di_out[:5])
# Out:
# ['오랫동안', '한', '동네', '에서', '살았던', '할머니', '인데', '돌아가', '겨', '서', '마음', '이', '아프네요']
# ['혈압', '약', '은', '시간', '을', '맞춰', '챙겨', '드셔야지', '안', '그러면', '효과', '가', '없습니다']
# ['집', '에', '돌아와', '보', '니까', '문', '이', '열려', '있고', '서랍', '이', '열어', '둔', '돈', '전부', '없어지던', '어이', '떼']
# ['아들', '오늘', '중요한', '시험', '보', '니까', '이', '생', '엿', '하고', '사서', '먹고', '힘내서', '시험', '잘', '봐']
# ['옛날', '부터', '조상', '꿈', '이나', '돼지', '꿈', '꾸면', '집', '에', '돈', '많이', '들어온다고', '좋아', '했죠']
# ['겨울', '에', '먹을', '채소', '나', '과일', '같은', '것', '은', '어디', '에', '보관', '을', '했습니까']
# ['친정', '동네', '하고', '이', '동네', '하고', '차례', '지낼', '때', '상', '차리는', '건', '뭐', '가', '다릅니까']
# ['친정', '동네', '하고', '이', '동네', '하고', '차례', '지낼', '때', '상', '차리는', '건', '뭐', '가', '다릅니까']
# ['촌', '구석', '이라', '젊은', '사람', '들', '은', '아예', '없고', '전부', '노인', '들', '만', '있으니까', '농사', '짓기가', '힘들어요']
# ['촌', '구석', '이라', '젊은', '사람', '들', '은', '한', '번', '이', '없고', '전부', '노인', '들', '만', '있으니까', '농사', '짓기가', '힘들어요']
# ['소도', '사람', '처럼', '잘', '먹어야', '근육', '도', '붙고', '힘', '도', '생겨서', '일', '을', '잘', '하지요']
# ['소도', '사람', '처럼', '잘', '먹어야', '근육', '도', '붇', '고', '힘', '도', '생겨서', '일', '을', '잘', '하지요']
# ['옷감', '을', '자를', '때', '는', '미리', '선', '을', '그', '어', '놓아야', '똑바로', '잘', '자를', '수', '있어요']
# ['올해', '는', '배추', '농사', '를', '농사', '농사', '를', '망쳐서', '김장', '으로', '하려면', '배추', '를', '좀', '가져와서', '담가야', '되겠네']
# ['우리', '며느리', '는', '자식', '들', '잘', '챙기고', '착해서', '내', '가', '얼마나', '자랑', '을', '하고', '다닌다고']
# ['우리', '며느리', '는', '자식', '들', '잘', '챙기고', '착해서', '내', '가', '얼마나', '자랑', '을', '하고', '다닌다고']
# ['배추', '한', '포기', '키우는', '것', '도', '이렇게', '힘드는데', '어머니', '는', '어떻게', '평생', '농사', '를', '짓고', '살았습니까']
# ['배추', '한', '포기', '키우는', '것', '도', '이렇게', '힘드는데', '어머니', '는', '어떻게', '평생', '농사', '를', '짓고', '살았을까']
# ['비', '가', '올', '줄', '도', '모르고', '세차', '를', '하루', '종일', '열심히', '했는데', '완전히', '헛수', '고', '했다']
# ['비', '가', '올', '줄', '도', '모르고', '세차', '를', '하루', '종일', '열심히', '했는데', '완전히', '헛수', '고', '했네']
# ['세월', '이', '좋다만', '우리', '그때', '는', '하고', '싶은', '것', '도', '못', '하고', '공물', '이', '많아서']
# ['요새', '는', '시월', '이', '좋다만', '우리', '클', '때', '는', '하고', '싶은', '것', '도', '못', '하고', '고생', '이', '많았어']
# ['전화', '를', '하고', '싶었는데', '얘기', '를', '하는', '중간', '에', '전화', '와서', '나오기가', '어려웠기', '어', '어려워서', '집', '에', '전화', '못', '했다']
# ['전화', '를', '하고', '싶었는데', '얘기', '를', '하는', '중간', '에', '전화', '와서', '나오기가', '어', '어려워서', '집', '에', '전화', '못', '했다']
# ['어머니', '지금', '차', '타고', '장', '에', '나가려고', '하는데', '혹시', '읍내', '로', '나가시', '면', '태워', '드릴게요']
# ['어머니', '지금', '차', '타고', '저', '나가려고', '하는데', '혹시', '읍내', '로', '나가시', '면', '태워', '드릴게요']
# ['어깨', '가', '뻐근한데', '얼음찜질', '좀', '하게', '냉장고', '에', '얼음', '좀', '꺼내줘']
# ['어깨', '가', '뻐근한데', '얼음찜질', '좀', '하게', '냉장고', '에', '얼음', '좀', '꺼내', '줘']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금세', '잡초', '가', '자라서', '엉망', '진창', '돼요']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '도', '맛있다고', '따', '먹고', '그랬지요']
# ['제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들여야', '합니다']
# ['밭', '이', '별로', '크지도', '않으니까', '양배추', '보다는', '상추', '같은', '걸', '씹는', '게', '좋겠어요']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '합니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['도리깨', '가', '깨나', '무거워', '서', '허리', '에', '다칠', '수', '있으니까', '타작', '털', '때', '살살', '두드려']
# ['도리깨', '가', '깨나', '무거워', '서', '허리', '에', '다칠', '수', '있으니까', '타작', '털', '때', '살살', '두드려']
# ['옛날', '에는', '특별한', '간식', '이', '없으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '그랬어요']
# ['장작', '으로', '쓸', '나무', '는', '쪼개서', '저쪽', '담장', '에', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드세요']
# ['여기', '까지', '오시느라', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드세요']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네요']
# ['오랜', '만', '에', '가족', '끼리', '와서', '외식', '한번', '하자', '고', '하는데', '그것', '도', '못', '하면', '어떡해요']
# ['평생', '을', '농사', '만', '지으니까', '허리', '가', '굽어서', '이제', '는', '똑바로', '걸', '을', '수가', '없습니다']
# ['평생', '을', '농사', '만', '지으니까', '허리', '가', '굽어서', '이제', '는', '똑바로', '그럴', '수가', '없습니다']
# ['닭', '을', '닭', '의장', '에', '넣어', '두지', '않으면', '밤', '에', '산', '짐승', '이', '내려', '내려와서', '물', '고', '가', '버립니다']
# ['비단', '을', '어떻게', '짜는지', '그', '과정', '을', '한번', '좀', '말씀', '해', '주', '시', '렵', '니까']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수도', '있으니까', '정밀', '정말', '위험합니다']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수도', '있으니까', '정말', '정말', '위험합니다']
# ['자식', '들', '때문', '에', '열심히', '살았는데', '이제', '자식', '들', '이', '이렇게', '날', '챙겨주니까', '고맙지']
# ['자식', '들', '때문', '에', '열심히', '살았는데', '이제', '자식', '들', '이', '이렇게', '날', '챙겨주니까', '고맙지']
# ['태풍', '때문', '에', '바람', '이', '세게', '부', '니까', '산사태', '가', '날까봐', '잠', '을', '한숨', '도', '못', '잡니다']
# ['태풍', '때문', '에', '바람', '이', '세게', '부', '니까', '산사태', '가', '날까', '봐', '잠', '을', '한숨', '도', '못', '잡니다']
# ['베', '를', '짜다가', '줄이', '터져', '그만', '끊어진', '베', '를', '묶어', '연결해서', '다시', '짜야', '합니다']
# ['베', '를', '짜다가', '줄이', '터져', '버리면', '끊어진', '데', '를', '모두', '이어서', '다시', '짜야', '합니다']
# ['감기', '약', '먹고', '졸릴', '때', '는', '사고', '날', '수', '있으니까', '경운기', '몰지', '마세요']
# ['남자', '들', '은', '농악', '도', '하고', '씨름', '도', '하고', '여자', '들', '은', '강강수월래', '하면서', '놀았지요']
# ['된장국', '끓이고', '호박', '밥', '해서', '양념장', '으로', '비벼', '먹으면', '달콤한', '게', '맛있어요']
# ['올해', '는', '날씨', '가', '좋아서', '농사', '도', '잘', '되고', '밭', '떼기로', '팔고', '하니까', '기분', '좋습니다']
# ['올해', '는', '날씨', '가', '좋아서', '농사', '도', '잘', '됐고', '밭', '떼기로', '팔고', '하니까', '기분', '좋습니다']
# ['요새', '는', '시간', '이', '조금', '만', '지나도', '다', '잊어버리고', '물건', '도', '자주', '잃어버려서', '큰일', '입니다']
# ['요새', '는', '시간', '이', '조금', '만', '지나도', '다', '잊어버리고', '물건', '도', '자주', '잃어버리면', '버려서', '큰일', '입니다']
# ['마을', '모', '심는', '날', '에는', '사람', '들', '이', '같이', '여기저기', '다니면서', '품앗이', '를', '합니다']
# ['상량하', '면', '주인', '하고', '일꾼', '들', '이', '음식', '도', '나눠', '먹고', '술', '도', '마시고', '그랬어요']
# ['우리', '어머니', '는', '솜씨', '가', '좋아서', '옷', '도', '잘', '만들고', '음식', '도', '맛깔나게', '했습니다']
# ['인두', '를', '화로', '에', '올려놓고', '뜨겁게', '달구어서', '인두', '질', '을', '하지']
# ['인두', '를', '화로', '에', '올려놓고', '뜨겁게', '달구어서', '인두', '질', '을', '하지']
# ['지금', '얼른', '밥상', '부터', '차릴', '어', '테', '니까', '배', '가', '고프더라도', '조금', '만', '참으세요']
# ['지금', '얼른', '밥상', '부터', '차릴', '테', '니까', '배', '가', '고프더라도', '조금', '만', '참으세요']
# ['소', '는', '털', '이', '까만', '것', '도', '있고', '빨간', '것', '도', '있는데', '그래도', '누런', '게', '제일', '많지요']
# ['시', '아버님', '께서', '늦게까지', '안', '들어오면', '홀애비', '가', '불', '켜놓고', '밤새', '기다리고', '그럽', '그럽니다']
# ['시', '아버님', '께서', '늦게까지', '안', '들어오면', '홀애비', '가', '불', '켜놓고', '밤새', '기다리고', '그랬습니다']
# ['날', '이', '추우니까', '손', '은', '시리', '지만', '그래도', '우리', '일이', '니깐', '별로', '피곤한', '줄', '도', '모르겠다']
# ['올해', '는', '날씨', '도', '좋았고', '비도', '적당하게', '와서', '밭농사', '가', '정말', '잘', '된', '편이', '다']
# ['자식', '들', '서울', '에서', '직장', '다니는데', '바빠서', '연락', '은', '잘', '못', '해도', '잘', '잊지', '않겠습니까']
# ['자식', '들', '서울', '에서', '직장', '다니는데', '바빠서', '연락', '은', '잘', '못', '해도', '잘', '있지', '않겠습니까']
# ['아이', '가', '놀이', '공원', '에', '가자고', '저렇게', '조르는데', '바빠도', '한', '번은', '가', '봅시다']
# ['일이', '힘들어도', '돈', '벌리', '벌어서', '손주', '들', '용돈', '이라도', '줄', '수', '있으니까', '좋지']
# ['이', '구두', '신은', '지', '오', '년', '이', '지났으니까', '금', '이', '다', '닳아서', '이제', '는', '버려야겠다']
# ['나물', '무칠', '때', '는', '간', '을', '간간', '하게', '잘', '맞추어야지', '안', '그러면', '쓴맛', '이', '나서', '안', '돼']
# ['나물', '무칠', '때', '는', '간', '을', '간간', '하게', '잘', '맞추어야지', '안', '그러면', '쓴', '맛', '이', '나서', '안', '돼']
# ['담장', '은', '납작한', '돌멩이', '로', '가지', '고', '쭉', '이어', '만들기', '도', '하는데', '다', '그렇지는', '않아요']
# ['휴가', '때', '만', '되면', '사람', '들', '이', '여기', '놀러', '와서', '쓰레기', '를', '함부로', '버리니까', '지긋지긋합니다']
# ['휴가', '때', '만', '되면', '사람', '들', '이', '여기', '놀러', '와서', '쓰레기', '를', '함부로', '버리니까', '지긋지긋합니다']
# ['오늘', '비', '올', '것', '같으니까', '우산', '잘', '챙겨서', '잃어버리지', '말고', '단단히', '챙겨서', '와']
# ['오늘', '비', '올', '것', '같으니까', '우산', '잘', '챙겨가지고', '잃어버리지', '말고', '단단히', '챙겨서', '와라']
# ['여기는', '촌', '구석', '이라', '병원', '에', '가려고', '하면', '차', '를', '타고', '한참', '을', '나가야', '된다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '해', '요']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '해', '요']
# ['삼', '신', '할머니', '한테', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해', '달라', '고', '빌었지']
# ['아이', '가', '어제', '부터', '열', '이', '안', '떨어지는데', '이러다', '큰일', '나', '는', '게', '아닌지', '모르겠다']
# ['피', '가', '안', '멈추고', '이렇게', '계속', '나면', '병원', '에', '가봐야', '하는', '거', '아니에요']
# ['코피', '가', '안', '멈추고', '이렇게', '계속', '나면', '병원', '에', '가', '봐야', '하는', '거', '아닌가요']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '했어요']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '했어요']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '넣고', '꿰매서', '입었습니다']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '넣고', '꿰매서', '입었습니다']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '살았습니다']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '살았습니다']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사월', '초', '쯤', '되면', '먹을', '수', '있을', '겁니다']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사월', '초', '쯤', '되면', '먹을', '수', '있을', '겁니다']
# ['여기는', '시골', '이라', '교통', '이', '좀', '불편한데', '공기', '도', '깨끗하게', '경치', '가', '참', '좋아요']
# ['여기는', '시골', '이라', '교통', '이', '좀', '불편한데', '공기', '도', '개운한게', '경치', '가', '참', '좋아요']
# ['시래기', '를', '새끼', '줄', '에', '엮어', '서', '말려놨다가', '나중', '에', '국', '끓일', '때', '넣어', '먹으면', '맛있어요']
# ['시래기', '를', '새끼', '에', '엮어', '서', '말려놨다가', '나중', '에', '국', '끓일', '때', '넣어', '먹으면', '맛있어요']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '이', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '이', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['빨리', '먹으면', '과식', '하게', '되니까', '배고파도', '찬찬히', '드시기', '좋습니다']
# ['비', '가', '많이', '오면', '축대', '부터', '살피', '고', '위험하다', '싶으면', '얼른', '집', '에서', '나와야', '합니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['두릅', '은', '살짝', '데', '쳐서', '무쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '했어요']
# ['어릴', '때', '학교', '를', '못', '가고', '풀', '베러', '가고', '소', '풀', '먹이러', '다니고', '그랬습니다']
# ['어깨', '가', '뻐근한데', '얼음', '찜질', '좀', '하게', '하게', '냉장고', '에', '얼음', '좀', '꺼내', '줘']
# ['어깨', '가', '뻐근한데', '얼음', '찜질', '좀', '하고', '하고', '냉장고', '에', '얼음', '좀', '꺼내줘']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금새', '잡초', '가', '자라서', '엉망', '이', '됩니다']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금세', '잡초', '가', '자라서', '엉망', '이', '됩니다']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '을', '맛있다고', '따', '먹고', '그랬지요']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '을', '맛있다고', '다', '먹고', '그랬지요']
# ['제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들여서', '해야', '합니다']
# ['밭', '이', '별로', '크지도', '않았으니까', '양배추', '보다는', '상추', '같은', '걸', '심는', '게', '좋겠어요']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '합니다']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '합니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['다리', '도', '아프고', '날', '이', '따가우니까', '저기', '그늘', '에서', '잠시', '쉬었다', '갑시다']
# ['다리', '도', '아프고', '날', '이', '따가우니까', '저기', '그늘', '에서', '잠시', '쉬었다', '갔다', '갑시다']
# ['도리깨', '가', '꽤', '나', '무거워', '서', '허리', '다칠', '수', '있으니까', '타작', '할', '때', '는', '살살', '두려', '두드려']
# ['도리깨', '가', '깨나', '무거워', '서', '허리', '다칠', '수', '있으니까', '다작', '할', '때', '는', '살살', '두려', '두드려']
# ['옛날', '에는', '특별한', '간식', '이', '없으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '그랬어요']
# ['동강', '으로', '쓸', '나무', '는', '또', '갈라', '가지', '고', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니까']
# ['여기', '까지', '오시느라고', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드십시오']
# ['여기', '까지', '오시느라고', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드십시오']
# ['지진', '이', '일어나', '일어나면', '퍼뜩', '얼른', '책상', '밑', '으로', '들어가서', '멈출', '때', '까지', '기다려야', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네']
# ['오랜', '만', '에', '가족', '끼리', '외식', '한번', '하자', '고', '했는데', '그것', '도', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '보이는데', '전', '부터', '내', '가', '옷', '좀', '사', '입으라고', '하지', '않았니']
# ['비단', '을', '어떻게', '짜는지', '그', '과정', '을', '한', '번', '좀', '말씀', '해', '주시겠습니까']
# ['이단', '을', '어찌', '짜는지', '그', '과정', '을', '한번', '조금', '말씀', '해', '주실랍니까']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수도', '있으니까', '정말', '위험합니다']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수도', '있으니까', '정말', '위험합니다']
# ['자식', '들', '때문', '에', '열심히', '살았는데', '이제', '자식', '들', '이', '이래', '날', '챙겨주니까', '고맙지']
# ['자식', '들', '때문', '에', '열심히', '살았는데', '이제', '자식', '들', '이', '이렇게', '날', '챙겨주니까', '고맙지']
# ['태풍', '때문', '에', '바람', '이', '세게', '부', '니까', '산사태', '날까봐', '잠', '을', '잘', '수도', '잠', '을', '한숨', '도', '못', '잤습니다']
# ['배틀', '짜다가', '줄이', '터져', '버리면', '끊어진', '데', '를', '모두', '이어서', '다시', '짜야', '합니다']
# ['동네', '에서', '무슨', '사고', '라도', '생기', '면', '마을', '사람', '들', '이', '무당', '불러서', '굿', '하고', '그랬어요']
# ['감기', '약', '먹고', '졸릴', '때', '는', '사고', '날', '수도', '있으니까', '경운기', '몰지', '마십시오']
# ['남자', '들', '은', '농악', '도', '하고', '씨름', '도', '하고', '여자', '들', '은', '강강술래', '하면서', '놀았죠']
# ['된장국', '끓이고', '호박', '밥', '해서', '양념장', '으로', '비벼', '먹으면', '달콤한', '게', '맛있습니다']
# ['올해', '는', '날씨', '가', '좋아서', '농사', '도', '잘', '되고', '밭', '도', '팔고', '하니까', '기분', '좋습니다']
# ['요새', '는', '시간', '이', '조금', '만', '지나도', '다', '잊어버리고', '물건', '도', '자주', '잊어버려서', '큰일', '입니다']
# ['마을', '모심는', '날', '에는', '사람', '들', '이', '같이', '여기저기', '다니면서', '품앗이', '를', '합니다']
# ['마을', '모심는', '날', '에는', '사람', '들', '이', '같이', '여기저기', '다니면서', '품', '품앗이', '를', '합니다']
# ['상량하', '면', '주인', '하고', '일꾼', '들', '이', '음식', '도', '나눠', '먹고', '술', '도', '마시고', '그랬습니다']
# ['우리', '어머니', '는', '솜씨', '가', '좋아가지고', '옷', '도', '잘', '만들고', '음식', '도', '맛깔나게', '만듭니', '다']
# ['우리', '어머니', '는', '솜씨', '가', '좋아가지고', '옷', '도', '잘', '만들고', '음식', '도', '맛깔나게', '만듭니', '다']
# ['인두', '를', '화로', '에', '올려놓고', '뜨겁게', '달궈서', '인두', '질', '을', '하세요']
# ['지금', '얼른', '밥상', '부터', '차릴', '테', '니까', '배', '가', '고프더라도', '조금', '만', '참으세요']
# ['소', '는', '털', '이', '까만', '것', '도', '있고', '빨간', '것', '도', '있는데', '그래도', '누런', '게', '제일', '많죠']
# ['시', '아버님', '께서', '늦게까지', '안', '들어오면', '허전해서', '불', '켜', '놓고', '밤새', '기다리고', '그랬습니다']
# ['날', '이', '춥고', '손', '도', '시리', '지만', '그래도', '우리', '일이', '니까', '별로', '피곤한', '줄', '모르겠습니다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '합니다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '합니다']
# ['삼신', '할머니', '한', '데', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해', '달라', '고', '빌었다']
# ['삼신할매', '한테', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하', '하게', '해', '달라', '고', '빌었지요']
# ['아이', '어제', '부터', '열', '이', '안', '떨어지는데', '이러다', '큰일', '나', '는', '거', '아닌지', '모르겠습니다']
# ['코피', '가', '멈추고', '이래', '계속', '나면', '병원', '에', '가', '봐야', '되는', '거', '아닌가']
# ['코피', '가', '안', '멈추고', '이렇게', '계속', '나오면', '병원', '에', '가봐야', '되는', '거', '아닌가']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '했어요']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '넣고', '꿰매서', '입었습니다']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '살았습니다']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '살았습니다']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사월', '초', '쯤', '되면', '먹을', '수', '있을', '겁니다']
# ['시래기', '를', '새끼', '에', '엮어', '서', '말려', '놨다', '가', '나중', '에', '국', '끓일', '때', '넣어서', '먹으면', '참', '맛있어요']
# ['시래기', '를', '새끼', '에', '엮어', '서', '말려', '놨다', '가', '나중', '에', '국', '끓일', '때', '넣어서', '먹으면', '참', '맛있어요']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['방', '에', '가래떡', '하고', '술', '을', '차려놓았으니까', '편하게', '드시면서', '말씀', '나누십시오']
# ['빨리', '먹으면', '과식', '되니까', '배고파도', '천천히', '드시는', '게', '좋습니다']
# ['비', '가', '많이', '오면', '축대', '부터', '살피', '고', '위험하다', '싶으면', '얼른', '집', '으로', '나와', '집', '에서', '나와야', '합니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['두릅', '은', '살짝', '데', '쳐서', '무쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '했어요']
# ['두릅', '은', '살짝', '데', '쳐서', '무쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '했어요']
# ['어릴', '때', '학교', '는', '못', '가고', '풀', '베러', '가고', '소', '풀', '먹이러', '다니고', '그랬습니다']
# ['어릴', '때', '학교', '는', '못', '가고', '풀', '베러', '가고', '소', '풀', '먹이러', '다니고', '그랬습니다']
# ['여름철', '에는', '모든', '음식', '을', '잘', '익혀서', '먹고', '물', '도', '꼭', '끓인', '것', '만', '드셔야', '됩니다']
# ['모기향', '을', '피우면', '화재', '위험', '이', '있으니까', '모기', '장', '을', '쳐놓고', '주무시는', '게', '좋습니다']
# ['엘리베이터', '에', '갇히면', '억지로', '나오려고', '하지', '말고', '비상', '벨', '을', '눌러서', '도움', '을', '청', '하세요']
# ['스님', '이', '시주', '하러', '오면', '많이는', '못', '드려도', '쌀', '은', '조금씩', '담아', '드리고', '그랬습니다']
# ['일', '을', '잘', '할', '수', '있으면', '자기', '가', '맡아서', '하든', '지', '아니면', '당신', '이', '잔소리', '를', '하지', '말아야지']
# ['베틀', '로', '옷', '을', '만들어', '가지', '고', '입으셨다고', '했는데', '옷', '만드는', '과정', '을', '알려주실랍니까']
# ['배틀', '로', '옷', '을', '만들어', '가지', '고', '입으셨다고', '했는데', '옷', '만드는', '과정', '을', '알라', '알려', '주시겠어요']
# ['우리', '며느리', '는', '농사', '일', '은', '잘', '못', '해도', '청소', '하나', '는', '정', '갈스럽게', '잘', '합니다']
# ['우리', '며느리', '는', '농사', '일', '은', '잘', '못', '해도', '청소', '는', '정', '갈스럽게', '잘', '합니다']
# ['점심', '때', '돌잔치', '가서', '어찌나', '많이', '먹었는지', '배불러서', '저녁', '을', '못', '먹겠습니다']
# ['점심', '때', '돌잔치', '가서', '어찌나', '많이', '먹었는지', '배불러서', '저녁', '을', '못', '먹겠습니다']
# ['처음', '에는', '형', '한테', '화가', '많이', '났었는데', '이야기', '를', '듣다', '보', '니까', '이해', '되더라고요']
# ['처음', '에는', '형', '한테', '화가', '많이', '났었는데', '이야기', '를', '듣다', '보', '니까', '이해', '되더라고요']
# ['삼베', '는', '하루', '저녁', '이', '면', '많이', '짜는데', '명주', '는', '촘촘해', '서', '암만', '짜도', '많이', '못', '짭니다']
# ['삼베', '는', '하루', '저녁', '이', '면', '많이', '짜는데', '명주', '는', '촘촘해', '서', '암만', '짜도', '많이', '못', '짭니다']
# ['가스레인지', '에', '불', '켜놓은', '걸', '잊어버리고', '음식', '을', '모두', '태울', '뻔했어요']
# ['가스레인지', '에', '불', '켜놓은', '걸', '잊어버리고', '의식', '을', '모두', '태울', '뻔했어요']
# ['오랫동안', '한', '동네', '에', '살았던', '할머니', '가', '돌아가셔서', '정말', '마음', '이', '아픕니다']
# ['오랫동안', '한', '동네', '에', '살았던', '할머니', '가', '돌아가셔서', '정말', '마음', '이', '아픕니다']
# ['혈압', '약', '은', '시간', '을', '맞춰서', '챙겨', '드셔야지', '안', '그러면', '효과', '가', '없습니다']
# ['집', '에', '돌아와', '보니', '문', '이', '열려', '있고', '서랍', '에', '넣어', '둔', '돈', '이', '전부', '없어졌습니다']
# ['아들', '오늘', '중요한', '시험', '보', '니까', '이', '갱엿', '하고', '찹쌀떡', '하고', '먹고', '힘내서', '시험', '잘', '봐라']
# ['아들', '오늘', '중요한', '시험', '보', '니까', '이', '갱엿', '하고', '찹쌀떡', '하고', '먹고', '힘내서', '시험', '잘', '봐라']
# ['옛날', '부터', '조상', '꿈', '이나', '돼지', '꿈', '꾸면', '집', '에', '돈', '들어온다고', '좋아했지요']
# ['겨울', '에', '먹을', '채소', '나', '과일', '같은', '것', '은', '오래', '보관', '했으니까']
# ['촌', '구석', '이라', '젊은', '사람', '은', '아예', '없고', '전부', '노인', '들', '만', '있으니까', '농사', '짓기도', '힘들어']
# ['소도', '사람', '처럼', '잘', '먹어야', '근육', '이', '붙고', '힘', '도', '생겨서', '일도', '잘', '하지요']
# ['옷감', '을', '자를', '때', '는', '미리', '선', '을', '그', '어', '놓아야', '똑바로', '잘', '자를', '수', '있어요']
# ['올해', '는', '배추', '농사', '를', '망쳐서', '김장', '을', '하려면', '배추', '를', '좀', '사', '와서', '담가야', '되겠네']
# ['우리', '며느리', '는', '자식', '들', '잘', '챙기고', '착해서', '내', '가', '얼마나', '자랑', '을', '하고', '다닌다고요']
# ['배추', '한', '포기', '키우는', '것', '도', '이렇게', '힘드는데', '어머님', '은', '어떻게', '평생', '농사', '를', '짓고', '사셨을까']
# ['비', '가', '올', '줄', '도', '모르고', '세차', '를', '하루', '종일', '열심히', '했는데', '완전', '헛수', '고', '했네']
# ['요새', '는', '세월', '이', '좋다면', '우리', '클', '때', '는', '학교', '우리', '클', '때', '는', '하고', '싶은', '것', '도', '못', '하고', '고생', '이', '많았어']
# ['전화', '를', '하고', '싶었는데', '에', '얘기', '하는', '중간', '에', '전화하려', '나오기가', '어려워서', '집', '에', '전화', '못', '했습니다']
# ['어머니', '지금', '차', '타고', '장', '에', '나가려고', '하는데', '혹시', '읍내', '로', '나가시', '면', '태워다', '드릴게요']
# ['어깨', '가', '뻐근한데', '얼음', '찜질', '좀', '하게', '냉장고', '에', '얼음', '좀', '꺼내', '줘']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금새', '잡초', '가', '자라서', '엉망', '이', '돼요']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '도', '맛있다고', '따', '먹고', '그랬지요']
# ['제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들여야', '됩니다']
# ['밭', '이', '별로', '크지도', '않으니까', '양배추', '보다는', '상추', '같은', '걸', '씹는', '게', '좋겠어요']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '합니다']
# ['산', '에', '가서', '조금', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['다리', '도', '아프고', '날', '이', '뜨거우니까', '여기', '그늘', '에서', '잠시', '쉬었다', '갑시다']
# ['도리깨', '가', '꽤', '나', '무거워', '서', '다리', '다칠', '수', '있으니까', '타작', '할', '때', '살살', '두드려']
# ['옛날', '에는', '특별한', '간식', '이', '없으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '끓였어요']
# ['장작', '으로', '쓸', '나무', '는', '쪼개서', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '고생', '했는데', '시원한', '물이', '라도', '한', '잔', '드십시오']
# ['지진', '이', '일어나면', '얼른', '책상', '밑', '으로', '들어가서', '멈출', '때', '까지', '기다려야', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네']
# ['오랜', '만', '에', '가족', '끼리', '외식', '한번', '하자', '고', '하는데', '그것', '도', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '보이는데', '전', '부터', '내', '가', '옷', '좀', '사', '입으라고', '하지', '않았니']
# ['처음', '시집', '왔을', '때', '생선', '국', '을', '보고', '이', '거', '비린내가', '나서', '어떻게', '먹을지', '걱정', '했습니다']
# ['밀감', '이', '넘어', '써서', '못', '먹겠는데', '냉장고', '에', '다른', '과일', '있으면', '좀', '내', '올래']
# ['오랜', '만', '에', '조카', '를', '보', '니까', '못', '알아볼', '정도', '로', '훌쩍', '커버', '려', '서', '깜짝', '놀랐어']
# ['수술', '비', '가', '한두', '푼', '이', '아닌데', '갑자기', '돈', '얘기', '를', '하면', '어쩌', '라는', '말', '이냐']
# ['추석', '때', '차례', '지내면서', '조상', '께', '감사하다고', '인사', '를', '잘', '해야', '된다']
# ['수박', '은', '큰', '게', '맛있다고', '하는데', '참외', '는', '작은', '게', '작은', '게', '맛있는', '겁', '니까']
# ['등', '에', '피부', '가', '다', '벗겨졌는데', '연고', '를', '바르니까', '희한하게', '금방', '가라앉네요']
# ['나이', '가', '드니까', '귀가', '어두워져서', '사람', '들', '이', '무슨', '말', '을', '해도', '잘', '못', '알아듣겠습니다']
# ['시', '아버님', '께서', '옷', '차려', '입고', '나가시', '면', '사람', '들', '이', '멋쟁이', '라고', '많이', '말씀', '하셨어요']
# ['왜놈', '들', '이', '쌀', '을', '다', '뺏어가', '버려서', '없으니까', '매일', '꽁', '보리밥', '밖에', '못', '먹었지']
# ['쇠독', '에', '걸리면', '얼굴', '이', '노랗게', '되어서', '사람', '이', '기운', '이', '하나', '도', '없어', '보입니다']
# ['돼지', '머리', '갖다', '놓고', '굿판', '벌리면', '동네', '사람', '들', '쭉', '와서', '구경', '도', '하고', '그랬습니다']
# ['남', '의', '무', '구덩이', '가', '어디', '인지', '아는', '사람', '들', '은', '다른', '집', '무', '를', '빼', '가기', '도', '했지']
# ['뱀', '에', '물리', '면', '병원', '에', '가야', '지', '된장', '같은', '거', '마음대로', '바르면', '큰일', '납니다']
# ['평생', '을', '농사', '만', '지으니까', '허리', '가', '굽어서', '이제', '는', '똑바로', '걸', '을', '수가', '없습니다']
# ['닭', '을', '닭장', '에', '넣어', '두지', '않으면', '밤', '에', '산짐승', '이', '내려와서', '물어', '가', '버립니다']
# ['비단', '을', '어떻게', '짜는지', '그', '과정', '을', '한번', '좀', '말씀', '해', '주', '시', '렵', '니까']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수도', '있으니까', '정말', '위험합니다']
# ['자식', '들', '때문', '에', '열심히', '살았는데', '이제', '자식', '들', '이', '이런', '날', '챙겨주니까', '고맙지']
# ['베', '를', '짜다가', '줄이', '터져', '버리면', '끊어진', '데', '를', '모두', '이어서', '다시', '짜야', '합니다']
# ['동네', '에서', '무슨', '사고', '라도', '생기', '면', '마을', '사람', '들', '이', '무당', '불러서', '굿', '하고', '그랬어요']
# ['감기', '약', '먹고', '졸릴', '때', '는', '사고', '날', '수', '있으니까', '경운기', '몰지', '마십시오']
# ['남자', '들', '은', '농악', '도', '하고', '씨름', '도', '하고', '여자', '들', '은', '강강술래', '하면서', '놀았죠']
# ['된장국', '끓이고', '호박', '밥', '해서', '양념장', '으로', '비벼', '먹으면', '달콤한', '게', '맛있습니다']
# ['올해', '는', '날씨', '가', '좋아서', '농사', '도', '잘', '되고', '밭', '떼기로', '팔고', '하니까', '기분', '좋습니다']
# ['요새', '는', '시간', '이', '조금', '만', '지나도', '다', '잊어버리고', '물건', '도', '자주', '잃어버려서', '큰일', '입니다']
# ['마을', '모심은', '모', '모심은', '날', '에는', '사람', '들', '이', '같이', '여기저기', '다니면서', '품앗이', '를', '합니다']
# ['상량하', '면', '주인', '하고', '일꾼', '들', '이', '음식', '도', '나눠', '먹고', '술', '도', '마시고', '그랬습니다']
# ['우리', '어머니', '는', '솜씨', '가', '좋아서', '옷', '도', '잘', '만들고', '음식', '도', '맛있게', '했습니다']
# ['인두', '를', '화로', '에', '올려놓고', '뜨겁게', '달궈서', '인두', '질', '을', '하지']
# ['지금', '얼른', '밥상', '부터', '차릴', '테', '니까', '배', '가', '고프더라도', '조금', '만', '참으세요']
# ['소', '는', '이', '털', '이', '까만', '것', '도', '있고', '빨간', '것', '도', '있는데', '그래도', '누른', '게', '제일', '많지']
# ['시', '아버님', '께서', '늦게까지', '안', '들어오면', '허전해서', '불', '켜놓고', '밤새', '기다리고', '그랬습니다']
# ['날', '이', '추우니까', '손', '도', '시리', '지만', '그래도', '우리', '일이', '니까', '별로', '피곤한', '줄', '모르고', '줄', '도', '모르겠다']
# ['올해', '는', '날씨', '도', '좋았고', '비도', '적당하게', '와서', '밭농사', '가', '정말', '잘', '된', '편이', '야']
# ['자식', '들', '서울', '에서', '직장', '다니는데', '바빠서', '연락', '을', '잘', '못', '해도', '잘', '있지', '않겠습니까']
# ['애가', '놀이', '공원', '에', '가지', '고', '저렇게', '조르는데', '아', '가자고', '저렇게', '조르는데', '바빠도', '한번', '가봅시다']
# ['여유', '가', '있는', '사람', '들', '은', '기하', '집', '지을', '때', '보통', '몇', '칸', '짜리', '집', '을', '지었습니까']
# ['일이', '힘들어도', '돈', '벌어서', '손주', '들', '용돈', '이라도', '줄', '수', '있으니까', '좋지']
# ['이', '구도', '신은', '지', '년', '이', '지나', '니까', '금', '이', '다', '금', '이', '다', '닳아서', '이제', '는', '버려야겠다']
# ['날', '이', '더우면', '소금', '을', '조금', '넣고', '추우면', '많이', '넣고', '그', '래야', '맛', '이', '제대로', '납니다']
# ['나물', '무칠', '때', '는', '간', '을', '간간', '하게', '잘', '맞춰야', '야지', '안', '그러면', '쓴', '맛', '이', '나서', '안', '돼']
# ['담장', '은', '납작한', '돌멩이', '를', '가지', '고', '쭉', '이어', '만들기', '도', '하는데', '다', '그렇지는', '않아요']
# ['여기는', '전', '에', '살던', '데', '보다', '시절', '도', '좋고', '애', '들', '학교', '도', '정말', '가까워서', '좋아요']
# ['휴가', '때', '만', '되면', '사람', '들', '이', '여기', '놀러와', '서', '쓰레기', '를', '버리니까', '지긋지긋하다']
# ['오늘', '비', '올', '것', '같으니까', '우산', '챙겨가고', '잊어버리지', '말고', '잘', '챙겨서', '와라']
# ['여기는', '촌', '구석', '이라서', '병원', '에', '가려고', '하면', '차', '를', '타고', '한참', '을', '나가야', '됩니다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오히려', '오', '려고', '해', '요']
# ['삼신', '할머니', '한테', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해달라고', '빌었지']
# ['애가', '언제', '부터', '열', '이', '난', '떨어지면', '지는데', '이러다', '큰일', '나', '는', '거', '아닌지', '모르겠어']
# ['코피', '가', '안', '멈추고', '이래', '계속', '나면', '병원', '에', '가봐야', '하는', '거', '아니에요']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '했어요']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '넣고', '꿰매어', '입었습니다']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라고요']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '살았습니다']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사월', '초', '쯤', '되면', '먹을', '수', '있을', '겁니다']
# ['여기는', '시월', '이라', '교통', '이', '좀', '불편한데', '공기', '도', '깨끗하고', '경치', '가', '참', '좋아요']
# ['시래기', '를', '새끼', '에', '엮어', '서', '말려', '놨다', '가', '나중', '에', '국', '끓일', '때', '넣어서', '먹으면', '맛있어요']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '어', '여럿', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['방', '에', '가래떡', '하고', '술', '을', '차려', '놓았으니까', '편하게', '드시면서', '말씀', '나누세요']
# ['비', '가', '많이', '오면', '축대', '부터', '살피', '고', '위험하다', '싶으면', '얼른', '집', '에서', '나와야', '합니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['두릅', '은', '살짝', '데', '쳐서', '무쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '했어요']
# ['우리', '며느리', '는', '자식', '들', '잘', '챙', '챙기고', '착해서', '자기', '내', '가', '얼마나', '자랑', '을', '하고', '다니는지', '몰라요']
# ['배추', '한', '포기', '키우는', '것', '도', '이렇게', '힘든데', '어머님', '은', '어떻게', '평생', '농사', '를', '짓고', '사셨을까요']
# ['비', '가', '올', '줄', '도', '모르고', '세차', '를', '하루', '종일', '열심히', '했는데', '완전', '헛수고', '를', '했네요']
# ['요새', '는', '세월', '이', '좋아서', '우리', '클', '때', '하고', '싶은', '것', '도', '못', '하고', '고생', '이', '많았어요']
# ['전화', '를', '하고', '싶었는데', '얘기', '하는', '중간', '에', '전화하러', '나오기가', '어려워서', '집', '에', '전화', '를', '못', '했답니다']
# ['어머니', '지금', '차', '타고', '장', '에', '나가려고', '하는데', '혹시', '읍내', '나가시', '면', '태워다', '드릴게요']
# ['어깨', '가', '뻐근한데', '얼음', '찜질', '종', '하게', '낸', '잔고', '에', '얼음', '좀', '꺼내', '줘요']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금세', '잡초', '가', '자라서', '엉망', '이', '된답니다']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '도', '맛있다고', '딱', '먹고', '그랬지요']
# ['제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들여야', '됩니다']
# ['밭', '이', '별로', '크지도', '않으니까', '양배추', '보다는', '상추', '같은', '걸', '심는', '게', '좋겠어요']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘든', '힘들어서', '동네', '사람', '들', '하고', '같이', '한답니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['다리', '도', '아프고', '날', '이', '뜨거우니까', '저기', '그늘', '에', '잠시', '쉬었다', '갑시다']
# ['도리깨', '가', '깨나', '무거워', '서', '허리', '다칠', '수', '있으니까', '타작', '할', '때', '살살', '두르지요']
# ['옛날', '에는', '특별한', '간식', '이', '없으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '그랬어요']
# ['장작', '으로', '쓸', '나무', '는', '쪼개서', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드시죠']
# ['지진', '이', '일어나면', '얼른', '책상', '밑', '으로', '들어가서', '멈출', '때', '까지', '기다려야', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네요']
# ['오랜', '만', '에', '가족', '끼리', '외식', '한번', '하자', '고', '했는데', '그것', '도', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '보이는데', '전보', '다', '내', '가', '옷', '좀', '사', '입으라고', '하지', '않았니']
# ['처음', '시집', '왔을', '때', '생선', '국', '을', '보고', '이', '거', '비린내가', '나서', '어떻게', '먹을지', '걱정', '했습니다']
# ['여기는', '촌', '구석', '이라서', '병원', '에', '가려고', '하면은', '차', '를', '타고', '한참', '을', '나가야', '된답니다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '해', '요']
# ['삼신', '할머니', '한테', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해달라고', '빌었지']
# ['애가', '이제', '부터', '열', '이', '안', '떨어지면', '이러다', '큰일', '나', '는', '거', '아닌지', '모르겠어요']
# ['코피', '가', '안', '멈추고', '아래', '계속', '나면', '병원', '에', '가봐야', '하는', '거', '아니겠어요']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '했어요']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '넣고', '꿰매서', '입었답니다']
# ['지금', '안개', '도', '짙고', '파도', '가', '높아서', '배', '가', '전혀', '못', '다닌다고', '하더라고요']
# ['이웃', '이', '좀', '시끄러워도', '사이', '가', '불편해질', '까', '봐', '그냥', '참고', '산답니다']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사', '월', '초순', '되면', '먹을', '수', '있을', '겁니다']
# ['여기는', '시골', '이라', '교통', '이', '좀', '불편한데', '공기', '도', '깨끗하고', '경치', '가', '참', '좋아요']
# ['시래기', '를', '새끼', '에', '엮어', '서', '말려놨다가', '나중', '에', '국', '끓일', '때', '넣어서', '먹이', '면', '먹으면', '맛', '이', '있어요']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['방', '에', '가래떡', '하고', '술', '을', '차려', '놓았으니까', '편하게', '드시면서', '말씀', '나누시지요']
# ['빨리', '먹으면', '과식', '하게', '되니까', '배고파도', '천천히', '드시는', '게', '좋아요']
# ['비', '가', '많이', '오면', '축대', '부터', '살피', '고', '위험하다', '싶으면', '얼른', '집', '에서', '나와야', '합니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['두릅', '은', '살짝', '데', '쳐서', '무쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '한답니다']
# ['어릴', '때', '학교', '는', '못', '가고', '풀', '베러', '풀', '베러', '가고', '소', '풀', '먹이러', '다니고', '그랬었답니다']
# ['여름철', '엔', '모든', '음식', '을', '잘', '익혀서', '먹고', '물', '도', '꼭', '끓인', '것', '만', '드셔야', '돼요']
# ['모기향', '을', '피우면', '화재', '의', '위험', '이', '있으니까', '모', '기약', '을', '쳐놓고', '주무시는', '게', '좋답니다']
# ['엘리베이터', '에', '갇히면', '억지로', '나오려고', '하지', '말고', '비상', '벨', '을', '눌러서', '도움', '을', '청', '하세요']
# ['스님', '이', '시주', '하러', '오면', '많이', '못', '드려도', '쌀', '을', '조금씩', '담아', '드리고', '그랬습니다']
# ['일', '을', '잘', '할', '수', '있으면', '자기', '가', '맡아서', '하든', '지', '아니면', '당신', '이', '잔소리', '를', '하지', '말아야죠']
# ['베틀', '로', '옷', '을', '만들어', '입으셨다고', '했는데', '옷', '만드는', '과정', '을', '말씀', '해', '주실', '수', '있겠습니까']
# ['우리', '며느리', '는', '농사일', '을', '잘', '못', '해도', '청소', '하나', '는', '정', '갈스럽게', '잘', '한답니다']
# ['점심때', '돌잔치', '에', '가서', '어쩌담', '얼', '어찌나', '많이', '먹었는지', '배불러서', '저녁', '을', '못', '먹겠어요']
# ['처음', '에는', '혀', '형', '한테', '화가', '많이', '났었는데', '이야기', '를', '듣고', '보', '니까', '이해', '되더라고요']
# ['삼베', '는', '하루', '저녁', '이', '면', '많이', '짜는데', '명주', '는', '촘촘해', '서', '암만', '짜도', '많이', '못', '짜요']
# ['가스레인지', '에', '불', '켜놓은', '걸', '잊어버려서', '음식', '이', '모두', '태울', '뻔했어요']
# ['오랫동안', '한', '동네', '에서', '살았던', '할머니', '가', '돌아가셔서', '정말', '마음', '이', '아팠네요']
# ['약', '은', '시간', '을', '맞춰서', '챙겨', '드려야지', '안', '그러면', '효과', '가', '없습니다']
# ['집', '에', '돌아와', '보', '니까', '문', '이', '열려', '있고', '서랍', '에', '넣어', '둔', '돈', '이', '전부', '없어졌답니다']
# ...
# ['장작', '으로', '쓸', '나무', '는', '쪼개서', '쪼개서', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '욕', '봤는데', '시원한', '냉수', '부터', '한', '잔', '드시', '드시오']
# ['지진', '이', '일어나면', '얼른', '책상', '밑', '으로', '들어가', '멈출', '때', '까지', '기다려야', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네']
# ['오랜', '만', '에', '가족', '끼리', '외식', '한번', '하자', '고', '하는데', '그것', '도', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '비는데', '전', '부터', '좀', '내', '가', '옷', '좀', '사', '입으라고', '안', '했어']
# ['처음', '시집', '왔을', '때', '생선', '국', '을', '보고', '이', '거', '비린내가', '나나', '나서', '어떻게', '먹을지', '걱정', '했습니다']
# ['밀감', '이', '너무', '셔', '서', '못', '먹겠는데', '냉장고', '에', '다른', '과일', '있으면', '좀', '내', '올래']
# ['오랜', '만', '에', '조카', '를', '보', '니까', '못', '알아볼', '정도', '로', '훌쩍', '커', '버려서', '깜짝', '놀랐다']
# ['수술', '비', '가', '한두', '푼', '이', '아닌데', '갑자기', '돈', '이야기', '를', '하면', '어쩌', '라는', '말', '이냐']
# ['추석', '때', '차례', '지내면서', '조상', '한테', '감사하다고', '인사', '를', '잘', '해야', '된다']
# ['수박', '은', '큰', '게', '맛있다고', '하는데', '참외', '는', '작은', '게', '맛있는', '겁', '니까']
# ['비단', '을', '어떻게', '짰는지', '에', '그', '과정', '을', '한번', '좀', '말씀', '해', '주', '시', '렵', '니까']
# ['마을', '모심는', '날', '에는', '사람', '들', '이', '같이', '여기저기', '다니면서', '품앗이', '를', '합니다']
# ['여유', '가', '있는', '사람', '들', '은', '기와집', '지을', '때', '보통', '몇', '칸', '짜리', '집', '을', '지었습니까']
# ['삼', '신', '할머니', '한테', '에', '자식', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해', '달라', '고', '빌었지']
# ['방', '에', '가래떡', '하고', '술', '을', '차려', '놓았으니까', '편하게', '드시면서', '말씀', '나누시오']
# ['베틀', '로', '옷', '을', '만들어서', '입으셨다고', '했', '했는데', '옷', '만드는', '과정', '을', '알려', '주시겠어요']
# ['겨울', '에', '먹을', '채소', '나', '과일', '같은', '것', '은', '어디', '에', '보관', '을', '했습니까']
# ['친정', '동네', '하고', '이', '동네', '하고', '차례', '지낼', '때', '상', '차리는', '거', '뭐', '가', '다릅니까']
# ['어깨', '가', '뻐', '끈한데', '얼른', '찜질', '좀', '하게', '냉장고', '에', '얼음', '좀', '꺼내', '줘']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금새', '잡초', '가', '자라서', '엉망', '이', '돼요']
# ['옛날', '에는', '먹은', '것', '이', '없으니까', '겨울', '에', '고드름', '도', '맛있다고', '다', '먹고', '그랬지요']
# ['제사', '를', '제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들어야', '합니다']
# ['밭', '이', '별로', '크지도', '않으니까', '양배추', '보다는', '상추', '같은', '거', '심는', '게', '좋', '좋겠어']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '하더라']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['다리', '도', '아프고', '날', '이', '띠', '우', '거', '뜨거우니까', '저기', '그늘', '에서', '잠시', '쉬었다가', '갑시다']
# ['옛날', '에는', '특별한', '간식', '이', '없었으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '그랬어']
# ['장작', '으로', '쓸', '나무', '는', '잘라서', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '욕', '봤는데', '시원한', '물이', '라도', '한', '잔', '드세요']
# ['지진', '이', '일어', '만', '일어나면', '얼른', '책상', '밑', '으로', '들어가', '멈출', '때', '까지', '정', '기다려야', '할', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네']
# ['오랜', '만', '에', '가족', '짜리', '끼리', '외식', '한', '번', '하자', '고', '하는데', '그것', '은', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '빈', '보이는데', '전', '부터', '내', '가', '옷', '좀', '사', '입으라고', '않았니']
# ['처음', '시집', '왔을', '때', '생선', '국', '을', '보고', '이', '거', '비린내가', '나서', '어떻게', '먹을까', '걱정', '했습니다']
# ['밀감', '이', '너무', '시어', '서', '못', '먹겠다', '냉장고', '에', '다른', '과일', '있으면', '좀', '내', '올래']
# ['수술', '비', '가', '한두', '푼', '이', '아니다', '갑자기', '돈', '이야기', '하면', '어쩌라고', '말', '이야']
# ['추석', '때', '차례', '지내면서', '조상', '한테', '감사하다고', '인사', '를', '잘해야', '된다']
# ['수박', '은', '큰', '게', '맛있다고', '하는데', '참외', '는', '작은', '게', '맛있는', '건가']
# ['비단', '을', '어떻게', '짜는지', '그', '과정', '을', '한번', '좀', '말씀', '해', '주실랍니까', '꺼주실랍니까']
# ['마을', '모', '심는', '날', '에는', '사람', '들', '이', '같이', '여기', '저기', '다니면서', '품앗이', '를', '합니다']
# ['여유', '가', '있는', '사람', '들', '은', '기와집', '지을', '때', '보통', '몇', '칸', '자리', '집', '을', '지었습니까']
# ['삼신할매', '한', '데', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해', '달라', '고', '빌었지요']
# ['방', '에', '가래', '떡', '하고', '술', '을', '차려', '놓았으니', '까', '편하게', '드시면서', '말씀', '나누세요']
# ['베틀', '로', '옷', '을', '만들다가', '입으셨다고', '했는데', '옷', '만드는', '과정', '을', '말씀', '해', '주시겠어요']
# ['겨울', '에', '먹을', '채소', '나', '과일', '같은', '것', '을', '어디', '에', '보관', '을', '했습니까']
# ['등', '에', '피부', '가', '다', '벗겨졌었는데', '연고', '를', '바르니까', '희한하게', '금방', '가라앉았네']
# ['나이', '가', '드니까', '귀가', '어두워져서', '사람', '들', '이', '무슨', '말', '을', '해도', '잘', '못', '알아듣겠네']
# ['시', '아버님', '께서', '옷', '차려', '입고', '나가시', '면', '사람', '들', '이', '멋쟁이', '라고', '많이', '말씀', '하셨어요']
# ['왜놈', '들', '이', '쌀', '을', '다', '뺏고', '다', '버려', '없으니까', '매일', '꽁', '보리밥', '밖에', '못', '먹었지']
# ['돼지', '머리', '갖다', '놓고', '굿판', '벌리면', '동네', '사람', '들', '이', '쭉', '와서', '구경', '도', '하고', '그랬', '떠래', '습니다']
# ['남', '의', '무', '구덩이', '가', '어딘', '지', '아는', '사람', '은', '다른', '집', '무', '를', '빼앗기도', '했지요']
# ['뱀', '에', '물리', '면', '병원', '에', '가야', '지', '된장', '같은', '거', '마음대로', '바르면', '큰일', '난다']
# ['평생', '을', '농사', '만', '지었더니', '허리', '가', '굽어서', '이제', '는', '똑바로', '걸', '을', '수가', '없습니다']
# ['닭', '을', '닭장', '에', '넣어', '두지', '않으면', '밤', '에', '산짐승', '들', '이', '내려와서', '물어', '가', '버립니다']
# ['콘센트', '에', '코드', '를', '너무', '많이', '꽂으면', '불', '이', '날', '수', '있을텐데', '정말', '위험합니다']
# ['자식', '들', '때문', '에', '열심히', '살았더니', '이제', '자식', '들', '이', '이렇게', '날', '챙겨주겠네', '고맙지']
# ['베', '를', '짜다가', '줄이', '터져', '버리면', '끊어진', '데', '를', '모두', '이어서', '다시', '짜야', '합니다']
# ['동네', '에서', '무슨', '사고', '로', '생기', '면', '마을', '사람', '들', '이', '무당', '불러서', '굿', '하고', '그랬어요']
# ['감기', '약', '먹고', '졸릴', '때', '는', '사고', '날', '수', '있으니까', '갱', '경운기', '몰지', '마십시오']
# ['남자', '들', '은', '농약', '도', '하고', '농악', '도', '하고', '씨름', '도', '하고', '여자', '들', '은', '강강술래', '하면서', '놀았지']
# ['올해', '는', '날씨', '가', '좋아', '농사', '도', '잘', '됐고', '밭', '떼기로', '팔고', '하니까', '기분', '좋더라']
# ['요새', '는', '시간', '이', '조금', '만', '지나도', '다', '잊어버리고', '물건', '도', '자주', '잃어버려서', '큰일', '입니다']
# ['우리', '어', '어머니', '는', '솜씨', '가', '좋아서', '옷', '도', '잘', '만들고', '음식', '도', '맛있게', '했었지']
# ['인두', '를', '화로', '에', '올려', '놓고', '뜨겁게', '달', '궈', '서', '인두', '질', '을', '하지']
# ['지금', '얼른', '밥상', '부터', '차릴', '테', '니까', '배', '가', '고프더라도', '조금', '만', '참으세요']
# ['소', '는', '털', '까만', '것', '도', '있고', '빨간것도', '있는데', '그러게', '해도', '누런', '게', '제일', '많지로']
# ['시', '아버님', '께서', '늦게까지', '안', '들어오면', '허전해서', '불', '켜', '놓고', '밤새', '기다리고', '있더라']
# ['날', '이', '추우니까', '손', '도', '시리', '지만', '그래도', '우리', '일이', '니까', '별로', '피곤할', '줄', '도', '모른다']
# ['올해', '는', '날씨', '도', '좋았고', '비도', '적당하게', '와서', '밭농사', '가', '정말', '잘', '됐더라']
# ['자식', '들', '서울', '에', '직장', '다니는데', '바빠서', '연락', '을', '잘', '못', '해도', '잘', '있지', '않거든']
# ['애가', '놀이', '공원', '에', '가자고', '저렇게', '조르는데', '바빠도', '한', '번', '더', '가', '봅시다']
# ['일이', '힘들어도', '돈', '벌이', '가', '손주', '들', '용돈', '이라도', '줄', '수', '있으니까', '좋지요']
# ['이', '구두', '신은', '지', '오', '년', '이', '지나', '니까', '굽이', '다', '닳아서', '이제', '는', '내', '버려야겠다']
# ['날', '이', '더우면', '소금', '을', '조금', '넣고', '추우면', '많이', '넣고', '그', '래야', '맛', '이', '제대로', '납니다']
# ['나물', '무칠', '때', '간', '을', '강', '간간', '하게', '맞춰야지', '그렇지', '않으면', '맛', '이', '나서', '안', '돼']
# ['담장', '은', '납작한', '돌', '을', '가지', '고', '쭉', '이', '거', '서', '뺀', '것', '같기도', '하는데', '다', '그렇지는', '않더라']
# ['여기는', '전', '에', '살던', '데', '보다', '시설', '도', '좋고', '애', '들', '학교', '도', '잘만', '가까워서', '좋더라']
# ['휴가', '때', '만', '되면', '사람', '들', '이', '여기', '놀러와', '쓰레기', '를', '내', '버리', '기는', '지긋지긋하다']
# ['오늘', '비', '올', '것', '같은데', '우산', '챙겨가고', '잊어버리지', '말고', '단단히', '챙겨', '오', '너', '라']
# ['여기는', '촌', '구석', '이라', '비느', '병원', '에', '가려고', '하면', '차', '를', '타고', '한참', '나가야', '한다']
# ['가족', '끼리', '해돋이', '보면서', '새해', '다짐', '도', '하고', '소원', '도', '빌고', '오', '려고', '해', '요']
# ['애가', '어제', '부터', '열', '이', '안', '떨어지더라', '이', '이랬다', '칼', '나', '는', '거', '큰일', '나', '는', '거', '아닌지', '모르겠다']
# ['코피', '가', '안', '멈추고', '이렇게', '계속', '나면', '병원', '에', '가봐야', '하는데', '그', '아비', '있고']
# ['요새', '는', '예물', '도', '많이', '하지만', '옛날', '에', '우리', '결혼', '할', '때', '는', '생각', '도', '못', '한다']
# ['겨울', '에는', '바지', '저고리', '안', '에', '솜', '뭉치', '를', '여', '여', '넣고', '꿰매서', '입었더라']
# ['지금', '마', '안개', '도', '짙고', '파도', '가', '높아서', '배', '를', '전혀', '못', '다닌다고', '하더라']
# ['이웃', '이', '좀', '시끄러워서', '사이', '가', '불편해', '질까봐', '봐', '그냥', '참고', '살았더니']
# ['지난주', '에', '상추', '도', '심어', '놓았으니까', '사흘', '초', '되면', '먹을', '수', '있을', '꺼야']
# ['여기는', '시골', '이라', '교통', '이', '좀', '불편하고', '공기', '는', '깨끗하고', '경치', '가', '참', '좋더라']
# ['돼지', '잡', '을', '때', '는', '어른', '이', '여럿', '붙어야지', '안', '그러면', '힘들어서', '못', '잡습니다']
# ['빨리', '먹으면', '과식', '하게', '데니', '배', '고', '파도', '찬찬히', '드시는', '게', '좋다']
# ['비', '가', '많이', '오면', '축대', '부터', '살피', '고', '위험하다', '싶으면', '빨리', '집', '에서', '나와야', '합니다']
# ['운동', '을', '안', '하면', '좋은', '약', '을', '많이', '먹어도', '아무', '소용', '이', '없습니다']
# ['두릅', '은', '살짝', '데', '쳐', '무쳐', '뭉쳐', '먹기', '도', '하고', '고추장', '에', '찍어', '먹기', '도', '한다']
# ['어릴', '때', '학교', '학뇨', '는', '못', '가고', '풀', '베러', '가고', '소', '풀', '먹이러', '다니고', '그랬다']
# ['여름철', '에는', '모든', '음식', '을', '잘', '익혀', '먹고', '물', '도', '꼭', '챙길', '것', '만', '드셔야', '한', '다']
# ['모기향', '을', '피우면', '화재', '위험', '이', '있으니까', '모기', '장', '을', '쳐', '놓고', '주무시는', '게', '좋아요']
# ['엘리베이터', '에', '갇히면', '억지로', '나오려고', '하지', '말고', '비상', '벨', '을', '눌러서', '도움', '을', '청', '하세요']
# ['스님', '이', '시주', '하러', '오면', '많이는', '못', '드려도', '쌀', '을', '조금씩', '담아', '드리고', '그랬습니다']
# ['일', '을', '잘', '할', '수', '있으면', '지가', '맡아서', '하든', '지', '아니면', '당신', '이', '잔소리', '는', '하지', '말아야지']
# ['촌', '구석', '이라', '젊은', '사람', '은', '함부로', '없고', '전부', '노인', '들', '만', '있으니까', '농사짓기', '힘든데']
# ['소도', '사람', '처럼', '잘', '먹어야', '근육', '도', '붙고', '힘', '도', '생겨서', '일', '을', '잘', '하지요']
# ['꼭', '옷감', '을', '짜는', '데', '는', '미리', '선', '을', '그', '어', '놓아야', '똑', '바로', '잘', '지을', '수', '있어', '요']
# ['올해', '는', '배추', '농사', '를', '망쳐서', '김장', '을', '하려면', '배추', '를', '좀', '사와서', '담가야', '되거든']
# ['우리', '며느리', '는', '자식', '들', '잘', '챙기고', '착해서', '내', '가', '얼마나', '자랑', '을', '하고', '다닌다']
# ['배추', '한', '포기', '키우는', '것', '도', '이렇게', '힘드는데', '어머니', '는', '어떻게', '평생', '농사', '를', '짓고', '살았을까']
# ['비', '가', '올', '줄', '도', '모르고', '세차', '를', '하루', '종일', '열심히', '했거든', '완전히', '헛', '수고', '했더라']
# ['요새', '는', '세월', '이', '좋지만', '우리', '클', '때', '는', '하고', '싶은', '것', '도', '못', '하고', '고생', '이', '많았어']
# ['전화', '를', '하고', '싶은데', '얘기', '하고', '중간', '에', '전화하러', '나오기가', '어려워서', '집', '에', '전화', '못', '했어요']
# ['어머니', '지금', '차', '타고', '장', '에', '나갈려고', '하는데', '혹시', '읍내', '로', '나가시', '면', '태워다', '드릴게요']
# ['점심', '때', '돌잔치', '가서', '어찌나', '많이', '먹었는지', '배', '불러서', '저녁', '은', '못', '먹겠더라']
# ['처음', '에는', '형', '한테', '화가', '많이', '났는데', '이야기', '를', '듣다', '보', '니까', '이해', '가', '가더라']
# ['삼베', '는', '하루', '저녁', '이', '면', '많이', '짜는데', '명주', '는', '촘촘해', '서', '아무리', '짜도', '많이', '못', '짠다']
# ['가스레인지', '에', '불', '켜', '놓고', '잊어버려서', '음식', '을', '모두', '태울', '뻔했어요']
# ['오랫동안', '한', '동네', '에서', '살았던', '할머니', '인데', '돌아가셨거든', '마음', '이', '아프다', '한다']
# ['혈압', '약', '은', '시간', '을', '마', '춰서', '챙겨', '드셔야지', '안', '그러면', '효과', '가', '없어요', '없습니다']
# ['집', '에', '돌아와', '보', '니까', '문', '이', '열려', '있고', '서랍', '에', '넣어', '둔', '돈', '이', '전부', '없었다']
# ['아들', '오늘', '중요한', '시험', '보', '니까', '이', '갱', '엿', '넣고', '먹고', '찹쌀떡', '먹고', '힘내서', '시험', '잘', '쳐라']
# ['옛날', '부터', '조상', '꿈', '이나', '돼지', '꿈', '꾸면', '집', '에', '돈', '들어온다고', '좋아했지요']
# ['친정', '동네', '하고', '이', '동네', '하고', '차례', '지낼', '때', '상', '차리는', '건', '뭐', '가', '다릅니까']
# ['어깨', '가', '뻐근한데', '얼음', '찜질', '좀', '하게', '냉장고', '에', '얼음', '좀', '꺼내', '줘']
# ['마당', '을', '계속', '관리', '해야지', '안', '그러면', '금세', '잡초', '가', '자라서', '엉망', '이', '되어요']
# ['옛날', '에는', '먹을', '것', '이', '없으니까', '겨울', '에', '고드름', '도', '맛있다고', '따', '먹고', '그랬지요']
# ['제사', '를', '안', '모실', '것', '같으면', '모르지만', '제사', '를', '모실', '것', '같으면', '정성', '을', '들여야', '됩니다']
# ['발', '이', '별로', '크지도', '않으니까', '양배추', '보다는', '상추', '같은', '걸', '심는', '게', '좋겠어요']
# ['옛날', '에는', '혼자', '김장', '을', '했는데', '요즘', '은', '힘들어서', '동네', '사람', '들', '하고', '같이', '합니다']
# ['산', '에', '가서', '조금', '만', '다녀', '보면', '지팡이', '만들기', '좋은', '나무', '가', '아주', '많습니다']
# ['다리', '도', '아프고', '날', '이', '뜨거우니까', '저기', '그늘', '에서', '잠시', '쉬었다가', '갑시다']
# ['도리깨', '가', '꽤', '나', '무거워', '서', '허리', '다칠', '수', '있으니까', '타작', '털', '때', '살살', '두드려라']
# ['옛날', '에는', '특별한', '간식', '이', '없으니까', '옥수수', '나', '감자', '같은', '걸', '먹고', '그랬어요']
# ['장작', '으로', '쓸', '나무', '는', '쪼개서', '저쪽', '담장', '밑', '에', '쌓아', '두면', '됩니다']
# ['여기', '까지', '오시느라', '수고', '했는데', '시원한', '냉수', '부터', '한', '잔', '드세요']
# ['지진', '이', '일어나면', '빨리', '책상', '밑', '으로', '들어가', '멈출', '때', '까지', '기다려야', '합니다']
# ['요새', '날씨', '가', '가물어서', '농사', '도', '못', '짓고', '계속', '집', '에만', '있으니까', '정말', '답답하네']
# ['가족', '끼리', '외식', '한번', '하자', '고', '하는데', '그것', '도', '못', '하면', '어떡해요']
# ['새', '옷', '입으니까', '사람', '이', '달라', '비는데', '전', '부터', '내', '가', '옷', '좀', '사', '입으라고', '안', '했어']
# ['처음', '시집', '왔을', '때', '생선', '국', '을', '보고', '이', '거', '비린내가', '나서', '어떻게', '먹을지', '걱정', '했습니다']
# ['밀감', '이', '너무', '셔', '서', '못', '먹겠는데', '냉장고', '에', '다른', '과일', '있으면', '좀', '내', '올래']
# ['오랜', '만', '에', '조카', '를', '보', '니까', '못', '알아볼', '정도', '로', '훌쩍', '커', '버려서', '깜짝', '놀랐어']
# ['수술', '비', '가', '한두', '푼', '이', '아닌데', '갑자기', '돈', '이야기', '를', '하면', '어쩌', '라는', '말', '이냐']
# ['추석', '때', '차례', '지내면서', '조상', '한테', '감사하다고', '인사', '를', '잘', '해야', '된다']
# ['수박', '은', '큰', '게', '맛있다고', '하는데', '참외', '는', '작은', '게', '맛있는', '건', '거야']
# ['등', '에', '피부', '가', '다', '벗겨졌었는데', '연고', '를', '바르니까', '희한하게', '금방', '가라앉네요']
# ['나이', '가', '드니까', '귀가', '어두워져서', '사람', '들', '이', '무슨', '말', '을', '해도', '잘', '못', '알아듣겠습니다']
# ['시', '아버님', '께서', '옷', '차려', '입고', '나가시', '면', '사람', '들', '이', '멋쟁이', '라고', '많이', '말씀', '하셨어요']
# ['왜놈', '들', '이', '쌀', '을', '다', '뺏어', '가', '버려서', '없으니까', '매일', '꽁', '보리밥', '밖에', '못', '먹었지']
# ['채독', '에', '걸리면', '얼굴', '이', '노랗게', '돼', '가지', '고', '사람', '이', '기운', '이', '하나', '도', '없어', '보입니다']
# ['비단', '을', '어찌', '짜는지', '그', '과정', '을', '한번', '좀', '말씀', '해', '주시겠습니까']
# ['마을', '모심는', '날', '에는', '사람', '들', '이', '같이', '이리저리', '다니면서', '품앗이', '를', '합니다']
# ['여유', '가', '있는', '사람', '들', '은', '기와', '집', '지을', '때', '보통', '몇', '칸', '짜리', '집', '을', '지었습니까']
# ['삼신', '할머니', '한테', '자식', '들', '공부', '잘', '하고', '가족', '들', '건강하게', '해', '달라', '고', '빌었지']
# ['방', '에', '가래떡', '하고', '술', '을', '차려', '놓았으니까', '편하게', '드시면서', '말씀', '나누세요']
# ['배틀', '로', '옷', '을', '만들어서', '입으셨다고', '했는데', '옷', '만드는', '과정', '을', '알려주시겠어요']
# %%
sents_std_in[:3]

# %%
set(sents_std_in[0])

# %%
def build_vocab(sents):
  word_list = []

  for sent in sents:
      for word in sent:
        word_list.append(word)

  # 각 단어별 등장 빈도를 계산하여 등장 빈도가 높은 순서로 정렬
#   word_counts = Counter(word_list)
#   vocab = sorted(word_counts, key=word_counts.get, reverse=True)
  
  vocab = set(word_list)

  word_to_index = {}
  word_to_index['<PAD>'] = 0
  word_to_index['<UNK>'] = 1

  # 등장 빈도가 높은 단어일수록 낮은 정수를 부여
  for index, word in enumerate(vocab) :
    word_to_index[word] = index + 2

  return word_to_index

# %%
src_vocab = build_vocab(sents_std_in)
tar_vocab = build_vocab(sents_di_in + sents_di_out)

src_vocab_size = len(src_vocab)
tar_vocab_size = len(tar_vocab)
print("표준어 단어 집합의 크기 : {:d}, 방언 단어 집합의 크기 : {:d}".format(src_vocab_size, tar_vocab_size))
# Out:
# 표준어 단어 집합의 크기 : 5027, 방언 단어 집합의 크기 : 9256

# %%
src_vocab

# %%
index_to_src = {v: k for k, v in src_vocab.items()}
index_to_tar = {v: k for k, v in tar_vocab.items()}

def texts_to_sequences(sents, word_to_index):
  encoded_X_data = []
  for sent in sents:
    index_sequences = []
    for word in sent:
      try:
          index_sequences.append(word_to_index[word])
      except KeyError:
          index_sequences.append(word_to_index['<UNK>'])
    encoded_X_data.append(index_sequences)
  return encoded_X_data

# %%
encoder_input = texts_to_sequences(sents_std_in, src_vocab)
decoder_input = texts_to_sequences(sents_di_in, tar_vocab)
decoder_target = texts_to_sequences(sents_di_out, tar_vocab)

# %%
# 상위 5개의 샘플에 대해서 정수 인코딩 전, 후 문장 출력
# 인코더 입력이므로 <sos>나 <eos>가 없음
for i, (item1, item2) in zip(range(5), zip(sents_std_in, encoder_input)):
    print(f"Index: {i}, 정수 인코딩 전: {item1}, 정수 인코딩 후: {item2}")
# Out:
# Index: 0, 정수 인코딩 전: ['오랫동안', '한', '동네', '에서', '살았던', '할머니', '인데', '돌아가', '겨', '서', '마음', '이', '아프네요'], 정수 인코딩 후: [335, 3877, 1493, 4872, 3469, 40, 3850, 1841, 2420, 3902, 4867, 2985, 3702]
# Index: 1, 정수 인코딩 전: ['혈압', '약', '은', '시간', '을', '맞춰', '챙겨', '드셔야지', '안', '그러면', '효과', '가', '없습니다'], 정수 인코딩 후: [2436, 4787, 4753, 1402, 3662, 3647, 3012, 871, 1467, 2714, 1843, 2588, 1999]
# Index: 2, 정수 인코딩 전: ['집', '에', '돌아와', '보', '니까', '문', '이', '열려', '있고', '서랍', '이', '열어', '둔', '돈', '전부', '없어지던', '어이', '떼'], 정수 인코딩 후: [1320, 1345, 1737, 2010, 728, 4810, 2985, 4448, 781, 1178, 2985, 1922, 4361, 121, 1901, 3169, 1056, 1956]
# Index: 3, 정수 인코딩 전: ['아들', '오늘', '중요한', '시험', '보', '니까', '이', '생', '엿', '하고', '사서', '먹고', '힘내서', '시험', '잘', '봐'], 정수 인코딩 후: [282, 1568, 2481, 3246, 2010, 728, 2985, 1114, 790, 1928, 4221, 238, 1630, 3246, 4877, 3573]
# Index: 4, 정수 인코딩 전: ['옛날', '부터', '조상', '꿈', '이나', '돼지', '꿈', '꾸면', '집', '에', '돈', '많이', '들어온다고', '좋아', '했죠'], 정수 인코딩 후: [296, 1701, 2247, 879, 4262, 4713, 879, 3648, 1320, 1345, 121, 1006, 489, 1719, 3802]

# %%
def pad_sequences(sentences, max_len=None):
    # 최대 길이 값이 주어지지 않을 경우 데이터 내 최대 길이로 패딩
    if max_len is None:
        max_len = max([len(sentence) for sentence in sentences])

    features = np.zeros((len(sentences), max_len), dtype=int)
    for index, sentence in enumerate(sentences):
        if len(sentence) != 0:
            features[index, :len(sentence)] = np.array(sentence)[:max_len]
    return features

# %%
encoder_input = pad_sequences(encoder_input)
decoder_input = pad_sequences(decoder_input)
decoder_target = pad_sequences(decoder_target)

# %%
print('인코더의 입력의 크기(shape) :',encoder_input.shape)
print('디코더의 입력의 크기(shape) :',decoder_input.shape)
print('디코더의 레이블의 크기(shape) :',decoder_target.shape)
# Out:
# 인코더의 입력의 크기(shape) : (15296, 32)
# 디코더의 입력의 크기(shape) : (15296, 37)
# 디코더의 레이블의 크기(shape) : (15296, 37)

# %%
type( encoder_input )

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print('랜덤 시퀀스 :',indices)

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
print([index_to_src[word] for word in encoder_input[12300]])
print([index_to_tar[word] for word in decoder_input[12300]])
print([index_to_tar[word] for word in decoder_target[12300]])
# Out:
# ['뱀', '에', '몰리', '면', '병원', '에', '가야', '지', '된장', '같은', '거', '마음대로', '바르면', '큰일', '납니다', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['<sos>', '뱀', '에', '몰리', '면', '병원', '에', '가야', '지', '된장', '같은', '거', '마음대로', '바르면', '큰일', '남니', '더', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['뱀', '에', '몰리', '면', '병원', '에', '가야', '지', '된장', '같은', '거', '마음대로', '바르면', '큰일', '남니', '더', '<eos>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']

# %%
n_of_train = int(15296*0.8) +2
n_of_val = int(15296*0.1)
n_of_test = int(15296*0.1)


print('훈련 데이터의 개수 :',n_of_train)
print('검증 데이터의 개수 :',n_of_val)
print('테스트 데이터의 개수 :',n_of_test)

print("총합",n_of_train+n_of_val+n_of_test)
# Out:
# 훈련 데이터의 개수 : 12238
# 검증 데이터의 개수 : 1529
# 테스트 데이터의 개수 : 1529
# 총합 15296

# %%
encoder_input

# %%
encoder_input[n_of_train:n_of_train+n_of_val+1,:]

# %%
encoder_input_train = encoder_input[:n_of_train, :]
decoder_input_train = decoder_input[:n_of_train, :]
decoder_target_train = decoder_target[:n_of_train, :]

encoder_input_val = encoder_input[n_of_train:n_of_train+n_of_val+1, :]
decoder_input_val = decoder_input[n_of_train:n_of_train+n_of_val+1, :]
decoder_target_val = decoder_target[n_of_train:n_of_train+n_of_val+1, :]

encoder_input_test = encoder_input[-n_of_test:]
decoder_input_test = decoder_input[-n_of_test:]
decoder_target_test = decoder_target[-n_of_test:]

# %%
print('훈련 source 데이터의 크기 :',encoder_input_train.shape)
print('훈련 target 데이터의 크기 :',decoder_input_train.shape)
print('훈련 target 레이블의 크기 :',decoder_target_train.shape)
print()
print('검증 source 데이터의 크기 :',encoder_input_val.shape)
print('검증 target 데이터의 크기 :',decoder_input_val.shape)
print('검증 target 레이블의 크기 :',decoder_target_val.shape)
print()
print('테스트 source 데이터의 크기 :',encoder_input_test.shape)
print('테스트 target 데이터의 크기 :',decoder_input_test.shape)
print('테스트 target 레이블의 크기 :',decoder_target_test.shape)
# Out:
# 훈련 source 데이터의 크기 : (12238, 32)
# 훈련 target 데이터의 크기 : (12238, 37)
# 훈련 target 레이블의 크기 : (12238, 37)
#
# 검증 source 데이터의 크기 : (1530, 32)
# 검증 target 데이터의 크기 : (1530, 37)
# 검증 target 레이블의 크기 : (1530, 37)
#
# 테스트 source 데이터의 크기 : (1529, 32)
# 테스트 target 데이터의 크기 : (1529, 37)
# 테스트 target 레이블의 크기 : (1529, 37)

# %% [markdown]
# #### 번역기 만들기

# %%
import torch
import torch.nn as nn
import torch.optim as optim

embedding_dim = 256
hidden_units = 256

class Encoder(nn.Module):
    def __init__(self, src_vocab_size, embedding_dim, hidden_units):
        super(Encoder, self).__init__()
        self.embedding = nn.Embedding(src_vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_units, batch_first=True)

    def forward(self, x):
        # x.shape == (batch_size, seq_len, embedding_dim)
        x = self.embedding(x)
        # hidden.shape == (1, batch_size, hidden_units), cell.shape == (1, batch_size, hidden_units)
        _, (hidden, cell) = self.lstm(x)
        # 인코더의 출력은 hidden state, cell state
        return hidden, cell

class Decoder(nn.Module):
    def __init__(self, tar_vocab_size, embedding_dim, hidden_units):
        super(Decoder, self).__init__()
        self.embedding = nn.Embedding(tar_vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_units, batch_first=True)
        self.fc = nn.Linear(hidden_units, tar_vocab_size)

    def forward(self, x, hidden, cell):

        # x.shape == (batch_size, seq_len, embedding_dim)
        x = self.embedding(x)

        # 디코더의 LSTM으로 인코더의 hidden state, cell state를 전달.
        # output.shape == (batch_size, seq_len, hidden_units)
        # hidden.shape == (1, batch_size, hidden_units)
        # cell.shape == (1, batch_size, hidden_units)
        output, (hidden, cell) = self.lstm(x, (hidden, cell))

        # output.shape: (batch_size, seq_len, tar_vocab_size)
        output = self.fc(output)

        # 디코더의 출력은 예측값, hidden state, cell state
        return output, hidden, cell

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, trg):
        hidden, cell = self.encoder(src)

        # 훈련 중에는 디코더의 출력 중 오직 output만 사용한다.
        output, _, _ = self.decoder(trg, hidden, cell)
        return output

# %%
encoder = Encoder(src_vocab_size, embedding_dim, hidden_units)
decoder = Decoder(tar_vocab_size, embedding_dim, hidden_units)
model = Seq2Seq(encoder, decoder)

LR = 0.001
loss_function = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
print(model)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(5027, 256, padding_idx=0)
#     (lstm): LSTM(256, 256, batch_first=True)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(9256, 256, padding_idx=0)
#     (lstm): LSTM(256, 256, batch_first=True)
#     (fc): Linear(in_features=256, out_features=9256, bias=True)
#   )
# )

# %%
def evaluation(model, dataloader, loss_function, device):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_count = 0

    with torch.no_grad():
        for encoder_inputs, decoder_inputs, decoder_targets in dataloader:
            encoder_inputs = encoder_inputs.to(device)
            decoder_inputs = decoder_inputs.to(device)
            decoder_targets = decoder_targets.to(device)

            # 순방향 전파
            # outputs.shape == (batch_size, seq_len, tar_vocab_size)
            outputs = model(encoder_inputs, decoder_inputs)

            # 손실 계산
            # outputs.view(-1, outputs.size(-1))의 shape는 (batch_size * seq_len, tar_vocab_size)
            # decoder_targets.view(-1)의 shape는 (batch_size * seq_len)
            loss = loss_function(outputs.view(-1, outputs.size(-1)), decoder_targets.view(-1))
            total_loss += loss.item()

            # 정확도 계산 (패딩 토큰 제외)
            mask = decoder_targets != 0
            total_correct += ((outputs.argmax(dim=-1) == decoder_targets) * mask).sum().item()
            total_count += mask.sum().item()

    return total_loss / len(dataloader), total_correct / total_count

# %%
encoder_input_train_tensor = torch.tensor(encoder_input_train, dtype=torch.long)
decoder_input_train_tensor = torch.tensor(decoder_input_train, dtype=torch.long)
decoder_target_train_tensor = torch.tensor(decoder_target_train, dtype=torch.long)

encoder_input_val_tensor = torch.tensor(encoder_input_val, dtype=torch.long)
decoder_input_val_tensor = torch.tensor(decoder_input_val, dtype=torch.long)
decoder_target_val_tensor = torch.tensor(decoder_target_val, dtype=torch.long)

# 데이터셋 및 데이터로더 생성
batch_size = 128

train_dataset = TensorDataset(encoder_input_train_tensor, decoder_input_train_tensor, decoder_target_train_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = TensorDataset(encoder_input_val_tensor, decoder_input_val_tensor, decoder_target_val_tensor)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### 학습 설정

# %%
# 학습 설정
num_epochs = 20
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(5027, 256, padding_idx=0)
#     (lstm): LSTM(256, 256, batch_first=True)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(9256, 256, padding_idx=0)
#     (lstm): LSTM(256, 256, batch_first=True)
#     (fc): Linear(in_features=256, out_features=9256, bias=True)
#   )
# )

# %%
# Training loop
best_val_loss = float('inf')

train_history = {'Loss':[], 'Acc':[]}
valid_history = {'Loss':[], 'Acc':[]}


for epoch in range(num_epochs):
    # 훈련 모드
    model.train()

    for encoder_inputs, decoder_inputs, decoder_targets in train_dataloader:
        encoder_inputs = encoder_inputs.to(device)
        decoder_inputs = decoder_inputs.to(device)
        decoder_targets = decoder_targets.to(device)

        # 기울기 초기화
        optimizer.zero_grad()

        # 순방향 전파
        # outputs.shape == (batch_size, seq_len, tar_vocab_size)
        outputs = model(encoder_inputs, decoder_inputs)

        # 손실 계산 및 역방향 전파
        # outputs.view(-1, outputs.size(-1))의 shape는 (batch_size * seq_len, tar_vocab_size)
        # decoder_targets.view(-1)의 shape는 (batch_size * seq_len)
        loss = loss_function(outputs.view(-1, outputs.size(-1)), decoder_targets.view(-1))
        loss.backward()

        # 가중치 업데이트
        optimizer.step()

    train_loss, train_acc = evaluation(model, train_dataloader, loss_function, device)
    valid_loss, valid_acc = evaluation(model, valid_dataloader, loss_function, device)
    
    train_history['Loss'].append(train_loss)
    train_history['Acc'].append(train_acc)
    
    valid_history['Loss'].append(valid_loss)
    valid_history['Acc'].append(valid_acc)

    print(f'Epoch: {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Valid Loss: {valid_loss:.4f} | Valid Acc: {valid_acc:.4f}')

    # 검증 손실이 최소일 때 체크포인트 저장
    if valid_loss < best_val_loss:
        print(f'Validation loss improved from {best_val_loss:.4f} to {valid_loss:.4f}. 체크포인트를 저장합니다.')
        best_val_loss = valid_loss
        torch.save(model.state_dict(), 'best_model_okt.pth')
# Out:
# Epoch: 1/20 | Train Loss: 4.8904 | Train Acc: 0.2244 | Valid Loss: 4.9818 | Valid Acc: 0.2234
# Validation loss improved from inf to 4.9818. 체크포인트를 저장합니다.
# Epoch: 2/20 | Train Loss: 3.0156 | Train Acc: 0.5496 | Valid Loss: 3.1767 | Valid Acc: 0.5414
# Validation loss improved from 4.9818 to 3.1767. 체크포인트를 저장합니다.
# Epoch: 3/20 | Train Loss: 2.1507 | Train Acc: 0.6562 | Valid Loss: 2.3733 | Valid Acc: 0.6436
# Validation loss improved from 3.1767 to 2.3733. 체크포인트를 저장합니다.
# Epoch: 4/20 | Train Loss: 1.7742 | Train Acc: 0.6897 | Valid Loss: 2.0457 | Valid Acc: 0.6766
# Validation loss improved from 2.3733 to 2.0457. 체크포인트를 저장합니다.
# Epoch: 5/20 | Train Loss: 1.5489 | Train Acc: 0.7084 | Valid Loss: 1.8724 | Valid Acc: 0.6918
# Validation loss improved from 2.0457 to 1.8724. 체크포인트를 저장합니다.
# Epoch: 6/20 | Train Loss: 1.3677 | Train Acc: 0.7267 | Valid Loss: 1.7376 | Valid Acc: 0.7085
# Validation loss improved from 1.8724 to 1.7376. 체크포인트를 저장합니다.
# Epoch: 7/20 | Train Loss: 1.2013 | Train Acc: 0.7564 | Valid Loss: 1.6189 | Valid Acc: 0.7338
# Validation loss improved from 1.7376 to 1.6189. 체크포인트를 저장합니다.
# Epoch: 8/20 | Train Loss: 1.0576 | Train Acc: 0.7776 | Valid Loss: 1.5181 | Valid Acc: 0.7497
# Validation loss improved from 1.6189 to 1.5181. 체크포인트를 저장합니다.
# Epoch: 9/20 | Train Loss: 0.9540 | Train Acc: 0.7843 | Valid Loss: 1.4620 | Valid Acc: 0.7533
# Validation loss improved from 1.5181 to 1.4620. 체크포인트를 저장합니다.
# Epoch: 10/20 | Train Loss: 0.8806 | Train Acc: 0.7921 | Valid Loss: 1.4293 | Valid Acc: 0.7574
# Validation loss improved from 1.4620 to 1.4293. 체크포인트를 저장합니다.
# Epoch: 11/20 | Train Loss: 0.8225 | Train Acc: 0.7995 | Valid Loss: 1.4081 | Valid Acc: 0.7598
# Validation loss improved from 1.4293 to 1.4081. 체크포인트를 저장합니다.
# Epoch: 12/20 | Train Loss: 0.7734 | Train Acc: 0.8056 | Valid Loss: 1.3942 | Valid Acc: 0.7595
# Validation loss improved from 1.4081 to 1.3942. 체크포인트를 저장합니다.
# Epoch: 13/20 | Train Loss: 0.7304 | Train Acc: 0.8127 | Valid Loss: 1.3885 | Valid Acc: 0.7590
# Validation loss improved from 1.3942 to 1.3885. 체크포인트를 저장합니다.
# Epoch: 14/20 | Train Loss: 0.6934 | Train Acc: 0.8180 | Valid Loss: 1.3819 | Valid Acc: 0.7612
# Validation loss improved from 1.3885 to 1.3819. 체크포인트를 저장합니다.
# Epoch: 15/20 | Train Loss: 0.6602 | Train Acc: 0.8247 | Valid Loss: 1.3789 | Valid Acc: 0.7625
# Validation loss improved from 1.3819 to 1.3789. 체크포인트를 저장합니다.
# Epoch: 16/20 | Train Loss: 0.6270 | Train Acc: 0.8321 | Valid Loss: 1.3759 | Valid Acc: 0.7637
# Validation loss improved from 1.3789 to 1.3759. 체크포인트를 저장합니다.
# Epoch: 17/20 | Train Loss: 0.5977 | Train Acc: 0.8375 | Valid Loss: 1.3733 | Valid Acc: 0.7641
# Validation loss improved from 1.3759 to 1.3733. 체크포인트를 저장합니다.
# Epoch: 18/20 | Train Loss: 0.5708 | Train Acc: 0.8428 | Valid Loss: 1.3751 | Valid Acc: 0.7658
# Epoch: 19/20 | Train Loss: 0.5443 | Train Acc: 0.8487 | Valid Loss: 1.3750 | Valid Acc: 0.7636
# Epoch: 20/20 | Train Loss: 0.5218 | Train Acc: 0.8528 | Valid Loss: 1.3820 | Valid Acc: 0.7636

# %%
# show plot

TH = len(train_history['Loss'])
plt.figure(figsize=(10, 4))
# Loss
plt.subplot(1, 2, 1)
plt.plot(range(1, TH+1), train_history['Loss'], 'r-', label='Train')
plt.plot(range(1, TH+1), valid_history['Loss'], 'b-', label='Valid')
plt.grid()
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, TH+1), train_history['Acc'], 'r-', label='Train')
plt.plot(range(1, TH+1), valid_history['Acc'], 'b-', label='Valid')
plt.grid()
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# #### 모델 로드

# %%
# 모델 로드
model.load_state_dict(torch.load('best_model_okt.pth'))

# 모델을 device에 올립니다.
model.to(device)

# 검증 데이터에 대한 정확도와 손실 계산
val_loss, val_accuracy = evaluation(model, valid_dataloader, loss_function, device)

print(f'Best model validation loss: {val_loss:.4f}')
print(f'Best model validation accuracy: {val_accuracy:.4f}')
# Out:
# Best model validation loss: 1.3733
# Best model validation accuracy: 0.7641

# %%
print(tar_vocab['<sos>'])
print(tar_vocab['<eos>'])
# Out:
# 3738
# 1095

# %% [markdown]
# #### seq2seq 번역기 동작시키기

# %%
index_to_src = {v: k for k, v in src_vocab.items()}
index_to_tar = {v: k for k, v in tar_vocab.items()}

# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_src(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      sentence = sentence + index_to_src[encoded_word] + ' '
  return sentence

# 번역문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_tar(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0 and encoded_word != tar_vocab['<sos>'] and encoded_word != tar_vocab['<eos>']):
      sentence = sentence + index_to_tar[encoded_word] + ' '
  return sentence

# %%
print(encoder_input_test[25])
print(decoder_input_test[25])
print(decoder_target_test[25])

# %%
def decode_sequence(input_seq, model, src_vocab_size, tar_vocab_size, max_output_len, int_to_src_token, int_to_tar_token):
    encoder_inputs = torch.tensor(input_seq, dtype=torch.long).unsqueeze(0).to(device)

    # 인코더의 초기 상태 설정
    hidden, cell = model.encoder(encoder_inputs)

    # 시작 토큰 <sos>을 디코더의 첫 입력으로 설정
    # unsqueeze(0)는 배치 차원을 추가하기 위함.
    decoder_input = torch.tensor([3738], dtype=torch.long).unsqueeze(0).to(device)

    decoded_tokens = []

    # for문을 도는 것 == 디코더의 각 시점
    for _ in range(max_output_len):
        output, hidden, cell = model.decoder(decoder_input, hidden, cell)

        # 소프트맥스 회귀를 수행. 예측 단어의 인덱스
        output_token = output.argmax(dim=-1).item()

        # 종료 토큰 <eos>
        if output_token == 1095:
            break

        # 각 시점의 단어(정수)는 decoded_tokens에 누적하였다가 최종 번역 시퀀스로 리턴합니다.
        decoded_tokens.append(output_token)

        # 현재 시점의 예측. 다음 시점의 입력으로 사용된다.
        decoder_input = torch.tensor([output_token], dtype=torch.long).unsqueeze(0).to(device)

    return ' '.join(int_to_tar_token[token] for token in decoded_tokens)

# %%
encoder_input_test[1]

# %%
#### 번역 모델 결과 확인
for seq_index in [3, 50, 100, 304, 1004]:
  input_seq = encoder_input_test[seq_index]
  translated_text = decode_sequence(input_seq, model, src_vocab_size, tar_vocab_size, 100, index_to_src, index_to_tar)

  print("입력문장 :",seq_to_src(encoder_input_test[seq_index]))
  print("정답문장 :",seq_to_tar(decoder_input_test[seq_index]))
  print("번역문장 :",translated_text)
  print("-"*50)
# Out:
# 입력문장 : 수박 은 큰 게 맛있다고 하는데 참외 는 작은 게 맛있는 거 맛있다고 작은 게 맛있는 거 아닙니까
# 정답문장 : 수박 은 큰 기 맛있다고 카는데 참외 는 작은 게 맛있는 거 마시따꼬 작은 기 맛있는 거 아 입 니까
# 번역문장 : 수박 은 큰 게 맛있다고 하는디 참외 는 작은 게 맛있는 건교
# --------------------------------------------------
# 입력문장 : 지금 은 안개 도 짙고 파도 가 높아서 배 가 전혀 못 다닌다고 하더라고요
# 정답문장 : 지금 은 안개 도 짙고 파도 가 높아서 배 가 전혀 못 다닌다고 하더라 꼬 요
# 번역문장 : 지금 안개 도 짙고 파도 가 노파 가 배 가 만괴 몬 댕긴다꼬 하 대 예
# --------------------------------------------------
# 입력문장 : 요즘 날씨 가 가물어서 농사 도 못 짓고 계속 집 에만 있어서 정말 답답해
# 정답문장 : 오 새 날씨 가 가물어서 농사 도 몬 짓고 계속 집 에만 이 쓰이께네 정말 답답해
# 번역문장 : 요새 날씨 가 가물어서 농사 도 못 짓고 계속 집 에만 이 쓰이꺼네 정말 답답 네
# --------------------------------------------------
# 입력문장 : 배추 한 포기 키우는 것 도 이렇게 힘든데 어머니 는 어떻게 평생 농사 를 짓고 사셨을까
# 정답문장 : 배치 한 포기 키우는 것 도 이러쿠럼 힘든디 어 모이는 우 예 펭생 농새 를 짓고 사라 쓸라
# 번역문장 : 배치 한 포기 키우는 것 도 이러쿠럼 힘든디 어무이 는 우 예 평생 농사 를 짓고 사라 쓸라
# --------------------------------------------------
# 입력문장 : 여기는 시골 이라 교통 이 좀 불편한데 공기 도 깨끗하고 경치 가 참 좋아요
# 정답문장 : 여개 는 시골 이라 교통 이 쫌 불펜 한 디 공기 도 깨 끔하고 겡치 가 참 조 아예
# 번역문장 : 여기는 시골 이라 교통 이 좀 불편한디 공기 도 깨 끔하고 갱 치가 참 조 아예
# --------------------------------------------------

# %%
#### 번역 모델 결과 확인
for seq_index in [3, 50, 100, 304, 1004]:
  input_seq = encoder_input_test[seq_index]
  translated_text = decode_sequence(input_seq, model, src_vocab_size, tar_vocab_size, 100, index_to_src, index_to_tar)

  print("입력문장 :",seq_to_src(encoder_input_test[seq_index]))
  print("번역문장 :",translated_text)
  print("-"*50)
# Out:
# 입력문장 : 수박 은 큰 게 맛있다고 하는데 참외 는 작은 게 맛있는 거 맛있다고 작은 게 맛있는 거 아닙니까
# 번역문장 : 수박 은 큰 게 맛있다고 하는디 참외 는 작은 게 맛있는 건교
# --------------------------------------------------
# 입력문장 : 지금 은 안개 도 짙고 파도 가 높아서 배 가 전혀 못 다닌다고 하더라고요
# 번역문장 : 지금 안개 도 짙고 파도 가 노파 가 배 가 만괴 몬 댕긴다꼬 하 대 예
# --------------------------------------------------
# 입력문장 : 요즘 날씨 가 가물어서 농사 도 못 짓고 계속 집 에만 있어서 정말 답답해
# 번역문장 : 요새 날씨 가 가물어서 농사 도 못 짓고 계속 집 에만 이 쓰이꺼네 정말 답답 네
# --------------------------------------------------
# 입력문장 : 배추 한 포기 키우는 것 도 이렇게 힘든데 어머니 는 어떻게 평생 농사 를 짓고 사셨을까
# 번역문장 : 배치 한 포기 키우는 것 도 이러쿠럼 힘든디 어무이 는 우 예 평생 농사 를 짓고 사라 쓸라
# --------------------------------------------------
# 입력문장 : 여기는 시골 이라 교통 이 좀 불편한데 공기 도 깨끗하고 경치 가 참 좋아요
# 번역문장 : 여기는 시골 이라 교통 이 좀 불편한디 공기 도 깨 끔하고 갱 치가 참 조 아예
# --------------------------------------------------
