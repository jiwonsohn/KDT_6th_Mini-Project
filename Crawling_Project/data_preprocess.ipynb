# %% [markdown]
# #### clean_ML_info_500.csv 크롤링 데이터 항목 분리 & 저장
#
# * 지원 조건
# 	- 경력, 학력, 스킬, 핵심역량
#
# * 근무 조건
# 	- 고용형태
#
# * 기업 정보
# 	- 산업(업종), 기업형태

# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

from konlpy.tag import Okt
from wordcloud import WordCloud

import numpy as np
from PIL import Image

# %%
# DF 로드
raw = pd.read_csv('final_clean_ML_info_500.csv', encoding='utf-8-sig')
print(raw.iloc[0])
# Out:
# comp_name                                                   현대자동차㈜
# link             https://www.jobkorea.co.kr/Recruit/GI_Read/451...
# apply_require    경일력 경력 .학일력 학력무관 .핵심역량 계획성, 성실성, 꼼꼼함 .우대 기본우일대...
# condition                       고용형태 정규직 급여 회사내규에 따름 지역 서울시 서초구 지도
# comp_info        산업(업종) 승용차 및 기타 여객용 자동차 제조업 사원수 73,500명 설립년도 1...
# Name: 0, dtype: object

# %% [markdown]
# #### 지원 조건
# 	- 경력, 학력, 스킬, 핵심역량

# %%
data_dict = {}
columns = ['경력','학력','핵심역량', '스킬']

require = raw['apply_require'].to_list()
print(require[0])
print(require[0].split())
# Out:
# 경일력 경력 .학일력 학력무관 .핵심역량 계획성, 성실성, 꼼꼼함 .우대 기본우일대 장애인
# ['경일력', '경력', '.학일력', '학력무관', '.핵심역량', '계획성,', '성실성,', '꼼꼼함', '.우대', '기본우일대', '장애인']

# %%
tot_tmp_list = []
# print(tmp_list)

# %%
def clean_string(s):
    # 줄바꿈(\n, \r) 제거
    s = s.replace('\n', ' ').replace('\r', ' ')
    # 두 칸 이상의 공백을 하나의 공백으로 변경
    s = re.sub(r'\s{2,}', ' ', s)
    # "," 제거
    s = s.replace(",","")
    # 문자열 양쪽의 공백 제거
    return s.strip()

# %%
import re
import numpy as np

# %%
def extract(text):
	patterns ={
		"경력" : r"경일력\s*([^·.]+)",
		"학력" : r"학일력\s*([^.]+)",
		"스킬" : r"스킬\s*([^.]+)",
		"핵심역량": r"핵심역량\s*([^.]+)",
		"우대" : r"우대\s*([^.]+)"
	}

	result={}

	for k, v in patterns.items():
		match = re.search(v, text)
		if match:
			result[k] = match.group(1).strip()

	return result

period = [np.nan]*len(require)					# 경력
degree = [np.nan]*len(require)					# 학력
utility = [np.nan]*len(require)					# 역량
skill = [np.nan]*len(require)					# 스킬

for idx, r in enumerate(require):
	# print(extract(r))
	sss = extract(r)
	
	if '경력' in sss.keys():
		period[idx] = sss['경력']

	if '학력' in sss.keys():
		degree[idx] = sss['학력']

	if '핵심역량' in sss.keys():
		utility[idx] = sss['핵심역량']

	if '스킬' in sss.keys():
		skill[idx] = sss['스킬']

print(period[100:105])
print(degree[100:105])
print(utility[100:105])
print(skill[100:105])
# Out:
# {'경력': '경력', '학력': '학력무관', '핵심역량': '계획성, 성실성, 꼼꼼함', '우대': '기본우일대 장애인'}
# {'경력': '경력 직무에 따라 상이', '학력': '학력무관', '핵심역량': '성실성, 성취지향성, 계획성'}
# {'경력': '신입', '학력': '학력무관 교육별 상이', '스킬': 'Hadoop, JAVA, Python, Tensorflow, Tableau, ERP, MES, PLC'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'API, AWS, GCP, kubernetes, Python, Go', '핵심역량': '계획성, 성취지향성, 꼼꼼함'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'ASP, API, ASP'}
# {'경력': '신입', '학력': '학력무관', '스킬': ''}
# {'경력': '경력 (4년이상)', '학력': '대졸이상', '스킬': 'Pytorch, Tensorflow, Linux, CAD, BSP, MCU, Micom, RTOS', '핵심역량': '계획성, 성취지향성, 꼼꼼함', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '신입', '학력': '학력무관', '핵심역량': '계획성, 성실성, 꼼꼼함'}
# {'경력': '경력 (1년이상)', '학력': '학력무관', '핵심역량': '계획성, 성취지향성, 꼼꼼함', '우대': '기본우일대 장애인'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력 직무별 상이', '학력': '대졸이상 (ICT본부 고졸 이상)', '핵심역량': '계획성, 성실성, 꼼꼼함', '우대': '기본우일대 장애인'}
# {'경력': '경력 (10년이상)', '학력': '초대졸이상', '스킬': 'AWS, Hadoop, JAVA, Javascript, Kafka, Kotlin, OpenGL, Scala, Swift, Spring Framework'}
# {'경력': '경력', '학력': '학력무관', '핵심역량': '계획성, 성실성, 꼼꼼함'}
# {'경력': '신입', '학력': '학력무관', '우대': '기본우일대 인근거주자 우대전공 전기전자공학과'}
# {'경력': '경력 (1년이상)', '학력': '학력무관', '스킬': 'Ai, LLM'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'AWS, Azure, GCP, MySQL, NoSQL, SQL, Tensorflow, Linux', '우대': '기본우일대 장애인'}
# {'경력': '경력'}
# {'경력': '경력 (10년이상)', '학력': '학력무관', '스킬': 'JAVA, Python'}
# {'경력': '경력 (6년이상)', '학력': '학력무관', '스킬': 'Ai'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'JAVA, MySQL, Oracle, PHP, Python, Illustrator, Photoshop, 파이널컷, 프리미어, 영어'}
# {'경력': '신입', '학력': '학력무관', '스킬': '무선설비기사 자격, 운전면허, 전자기기기능사 자격, 정보기기운용기능사 자격, 정보보안기사 자격, 정보처리기능사 자격, 정보처리기사 자격, 정보처리산업기사 자격, 정보통신기사 자격, 토목기사 자격, 토목산업기사 자격', '핵심역량': '계획성, 성취지향성, 꼼꼼함'}
# {'경력': '경력', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'AWS, Git, GraphQL, Keras, MariaDB, MongoDB, Node', '핵심역량': '창의성, 성장지향성, 성실성, 협동심', '우대': '기본우일대 영어가능자 우대전공 전산학과'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'API, JAVA, Python', '핵심역량': '계획성, 성실성, 꼼꼼함, 적응성, 창의성, 협동심', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Docker, Hadoop, JAVA, Kafka, kubernetes, PostgreSQL, Python, Spark', '핵심역량': '계획성, 성실성, 꼼꼼함'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'MSSQL, Python, SQL'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'AWS, Python, Pytorch, Tensorflow, AWS EKS', '핵심역량': '협동심, 메타인지, 성취지향성', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C, C#, C++, HTML, iOS, JAVA, Javascript, Window, Linux, Cloud', '우대': '우대전공 정보통신공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'C#, C++, MSSQL, OpenCV, Oracle, Pytorch, CIM, RTD, mcs', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'C, C#, C++, Visual Studio, VIsualC·C++, C++Builder', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (7년이상)', '학력': '학력무관', '스킬': ''}
# {'경력': '경력'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Python, Pytorch, RestAPI, Tensorflow, Restful API'}
# {'경력': '경력 (8년이상)', '학력': '대졸이상', '스킬': 'Python', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Android, C#, Flutter, iOS, JAVA, Javascript, JSP, NoSQL, Oracle, Python, React, Spring, Vue', '핵심역량': '성실성, 꼼꼼함, 협동심', '우대': '기본우일대 운전가능자'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상', '핵심역량': '계획성, 성실성, 꼼꼼함', '우대': '기본우일대 박사학위 수여자'}
# {'경력': '경력 (4년이상)', '학력': '대졸이상'}
# {'경력': '경력 (1년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python', '핵심역량': '성실성, 성취지향성, 꼼꼼함, 스트레스관리, 성장지향성, 계획성, 윤리의식, 자존감, 적응성, 창의성, 협동심'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'JAVA, Python, React, OCR, NLP, LLM, RAG'}
# {'경력': '경력 (4년이상)', '학력': '학력무관', '우대': '기본우일대 영어가능자 우대전공 AI소프트웨어공학부'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'C, C#, C++, OpenCV', '우대': '기본우일대 인근거주자 우대전공 기계공학과'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'C, C++, Docker, Git, OpenGL, Python, Pytorch, Qt, Tensorflow, Verilog, Linux, Excel, OrCAD, 영어회화, DSP, MCU, Microsoft Office, PADs, UVM, WebSocket', '핵심역량': '계획성, 성취지향성, 꼼꼼함', '우대': '기본우일대 국가유공자 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': '주요', '핵심역량': '성취지향성, 꼼꼼함, 메타인지, 성실성, 창의성'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력 (4년이상)', '학력': '학력무관', '스킬': 'API, Azure, JAVA, Node', '핵심역량': '계획성, 성실성, 꼼꼼함', '우대': '기본우일대 장애인'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'JAVA, JSP'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'Docker, JAVA, Kafka, kubernetes, MySQL, Python, Pytorch, Tensorflow, Spring Framework, RDB', '우대': '기본우일대 국가유공자'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C, C++, Python', '우대': '기본우일대 관련 학과 전공자 우대전공 전기전자공학과'}
# {'경력': '신입', '학력': '대졸이상', '우대': '기본우일대 유관업무 경력자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '초대졸이상', '스킬': 'C, C#, C++, MFC, VIsualC·C++'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C, C++, JAVA, Javascript, Python, Pytorch, Swift, DL, 임베디드 소프트웨어, 임베디드 하드웨어'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력', '학력': '대졸이상', '우대': '기본우일대 한국신용정보원 3년 이상 근무 경력자 우대전공 통계학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C, C++, MSSQL, SAP, DBMS, 컨설팅, SW, 솔루션'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'C, C++, Git, Python, Pytorch, Linux, CUDA, Scikit-Learn, FFmpeg'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Python, C/C++, COMPUTER VISION, Machine Learning, Image processing'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력', '학력': '대학원(석사)이상'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'API, AWS, ElasticStack, Python, RDBMS, Spark, SQL', '핵심역량': '계획성, 꼼꼼함, 성실성'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C++, Git, Matlab, Python, Solidworks, 임베디드리눅스, AutoCAD, ROS, ROS2, Simulink', '핵심역량': '성실성, 윤리의식, 협동심, 성장지향성, 성취지향성, 계획성', '우대': '기본우일대 영어가능자 외국어 [영어] TOEIC 우대전공 기계공학과'}
# {'경력': '경력 (3년이상)', '학력': '고졸이상'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Python, SAS, SQL'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C, C++, JAVA', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C, C++, JAVA', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '핵심역량': '성실성, 꼼꼼함, 협동심, 적응성, 창의성', '우대': '기본우일대 운전가능자 우대전공 산업공학과'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '대졸이상', '우대': '기본우일대 국가유공자'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'AWS, Django, Docker, Hadoop, MongoDB, PostgreSQL, Python, ELK', '핵심역량': '창의성, 협동심, 성장지향성, 성실성, 꼼꼼함, 자존감, 적응성', '우대': '기본우일대 공모전 입상자'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Django, Flutter, MongoDB, MySQL, Python, React, TypeScript, Jotai, Langchain', '우대': '기본우일대 영어가능자 우대전공 산업공학과'}
# {'경력': '신입', '학력': '대학원(석사)이상'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Python, Pytorch, Tensorflow, Scikit-Learn', '핵심역량': '성실성, 성취지향성, 협동심, 성장지향성, 적응성', '우대': '기본우일대 병역특례'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'JAVA, Unix, Window, Linux, 클라우드, 정보보안, 인프라, 보안컨설팅, 데이터, it개발', '우대': '기본우일대 관련 자격증 보유자 우대전공 정보통신공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'API, AWS, GCP, PostgreSQL, Python, RestAPI, Vuex, Opensearch, Langchain, Qdrant', '핵심역량': '꼼꼼함, 협동심, 계획성', '우대': '기본우일대 유관업무 경력자(3년)'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, Pytorch'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Docker, Flask, kubernetes, Matlab, Python, Pytorch, R, Tensorflow'}
# {'경력': '경력 (1년이상)', '학력': '학력무관', '스킬': 'C++, Matlab, Python'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Pytorch, Tensorflow', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 영어가능자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (2년이상)', '학력': '대학원(석사)이상'}
# {'경력': '경력', '학력': '대학원(석사)이상'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Python, NLP, LLM, RAG'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C++, VisualBasic, VIsualC·C++'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Python'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'JAVA, Keras, MariaDB, Pytorch, Tensorflow, 전자정부표준프레임워크', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'C, C++, Python', '우대': '우대전공 공학계열'}
# {'경력': '신입', '학력': '학력무관', '핵심역량': '꼼꼼함, 성장지향성, 성실성, 성취지향성'}
# {'경력': '신입', '학력': '대학원(석사)이상', '핵심역량': '꼼꼼함, 성장지향성, 성실성, 성취지향성'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력 (5년이상)', '학력': '초대졸이상', '스킬': 'Git, Matlab, Pandas, Python, Pytorch, Scipy, Tensorflow, DL, Matplotlib, Numpy'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '자격증 정보처리기사'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '핵심역량': '계획성, 창의성, 성장지향성, 협동심, 적응성', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'MSSQL, MySQL, Python, R, SQL', '우대': '기본우일대 국가유공자 자격증 DAP 우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'JAVA, Javascript, Python, Spring, SQL', '우대': '기본우일대 장애인'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'C#, C++, MariaDB, OpenCV, WPF, DBMS, MVVM, TCP/IP, HTTP, MQTT', '핵심역량': '성실성, 성취지향성, 창의성, 협동심, 성장지향성, 계획성, 메타인지, 꼼꼼함, 스트레스관리, 윤리의식, 자존감, 적응성'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'JAVA, Kafka, Logstash, Python, SQL, Elasticsearch, Airflow, BigQuery, JSON, Kibana', '핵심역량': '스트레스관리, 적응성, 성장지향성, 성실성, 꼼꼼함', '우대': '기본우일대 컴퓨터활용능력 우수자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상'}
# {'경력': '경력 (5년이상)', '학력': '초대졸이상', '스킬': '', '핵심역량': '창의성, 협동심, 계획성, 성실성, 성취지향성, 꼼꼼함', '우대': '기본우일대 공모전 입상자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Python, Pytorch', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력 (1년이상)', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Window, Linux, TCP/IP, VLAN'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Hadoop, Oracle, Spark, Tensorflow, Window, Linux', '우대': '기본우일대 유관업무 경력자(2년)'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, Tensorflow, CNN', '우대': '기본우일대 통계분석·리서치 능숙자'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'OpenCV, Python, Pytorch, R, Tensorflow', '핵심역량': '성실성, 윤리의식, 창의성', '우대': '기본우일대 석사학위 수여자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'AWS, CSS, Django, Flask, HTML, Javascript, Python'}
# {'경력': '경력 (1년이상) 직무 별 상이', '학력': '대졸이상', '스킬': 'C, Matlab, Perl, Python, Verilog, System Verilog, 영어, 일본어, 중국어, Cadence, Microsoft Office, OPIc, TOEIC, TOEIC Speaking, UVM, 임베디드 소프트웨어', '우대': '기본우일대 장애인 외국어 [영어] TOEIC'}
# {'경력': '경력 (7년이상)', '학력': '대졸이상', '스킬': 'C, C#, C++, MFC, OpenCV, 머신러닝, 딥러닝, 이미지 프로세싱'}
# {'경력': '신입', '학력': '초대졸이상', '스킬': 'C#, Directx, WPF, Halcon, Euresys', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'C#, Directx, WPF, Halcon, Euresys', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Git, Python, Pytorch, Tensorflow, Unix, Linux'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'Python'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Keras, Python, Pytorch, Tensorflow', '핵심역량': '성실성, 창의성, 협동심', '우대': '기본우일대 학점우수(대졸 4'}
# {'경력': '경력 (1년이상)', '학력': '대졸이상', '스킬': 'Docker, Python, Pytorch, CNN, DL, GitHub, GitLab', '우대': '기본우일대 국가유공자'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Python, RDBMS, SQL, ERP, DBMS, NLP'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'C++, OpenCV, Python, Tensorflow, PyQt', '우대': '기본우일대 영어가능자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'SQL', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'C, C++'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'C, C++'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': '', '우대': '기본우일대 영어가능자 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Docker, kubernetes, Python, Linux, DL, Ai, ml, LLM, RAG', '핵심역량': '성실성, 성장지향성, 성취지향성'}
# {'경력': '경력 (1년이상)', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Pandas, Python, Pytorch, Airflow, Langchain', '핵심역량': '협동심, 성장지향성, 성실성'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': '3D, COMPUTER VISION, VSLAM'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'NLU, NLP, LLM, NLG'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, Pytorch, Tensorflow, DL, ml'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, Pytorch, Tensorflow, DL, ml'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, ml, Embedded'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, ml, Embedded'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'LLM, SLLM'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'LLM, SLLM'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C++, Python, Tensorflow, Ubuntu, 영상처리, 딥러닝, 임베디드'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, Ai, ml'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, Git, Python, Ai, ml'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C++, Python, Tensorflow, Ubuntu, 영상처리, 딥러닝, 임베디드, RDB, 웹 프론트'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Python, RDBMS, SQL, ERP, DBMS, NLP'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'AWS, Django, Git, Hadoop, MariaDB, MySQL, NoSQL, Python, Spark, Linux', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'API, CSS3, Git, HTML5, Javascript, Vue', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'AWS, JAVA, JPA, MariaDB, MyBatis, MySQL, Spring Boot, Linux, Restful API, ChatGPT', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'API, C++, Django, MariaDB, MySQL, NoSQL, Python, bigdata, ChatGPT', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'CSS3, HTML5, Adobe XD, Figma, Illustrator, Photoshop, UI, UX, D3', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Python, C/C++', '핵심역량': '계획성, 성실성, 꼼꼼함, 창의성, 성장지향성, 스트레스관리, 윤리의식, 성취지향성'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C++, Python, Pytorch, Tensorflow, ROS, SLAM, SVM, 자율주행, RMS', '핵심역량': '계획성, 성실성, 창의성, 협동심, 메타인지, 성장지향성, 성취지향성, 꼼꼼함, 스트레스관리', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C++, Python, Pytorch, Tensorflow, 영상처리', '우대': '기본우일대 유관업무 경력자(5년)'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'AWS, Pytorch, Tensorflow'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'C, C++, Python', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력 (6년이상)', '학력': '대졸이상', '우대': '기본우일대 석사이상 학위 소지자 우대'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Hadoop, Spark, SQL, Linux'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Pytorch, Tensorflow'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Python, Pytorch, Spark, Tensorflow'}
# {'경력': '경력', '학력': '대학원(석사)이상', '핵심역량': '꼼꼼함, 성장지향성, 성실성, 성취지향성'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'JAVA, kubernetes, OpenCV, Python, Pytorch, RDBMS, Vision', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (7년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'JAVA, MySQL, PHP, Python, SQL', '핵심역량': '성실성, 창의성, 협동심, 꼼꼼함', '우대': '기본우일대 프리젠테이션 능력우수자 자격증 정보처리기사 우대전공 산업공학과'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'OpenCV, Python, Pytorch, Matplotlib, Seaborn, plotly', '핵심역량': '성취지향성, 성장지향성, 계획성, 성실성, 꼼꼼함, 창의성, 협동심'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '초대졸이상', '스킬': 'C#, C++', '핵심역량': '성취지향성, 계획성, 적응성, 성장지향성, 창의성, 협동심, 성실성, 꼼꼼함, 스트레스관리, 윤리의식', '우대': '우대전공 정보통신공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'C, C#, C++, MFC, OpenCV, 머신러닝, 딥러닝, 이미지 프로세싱', '우대': '기본우일대 유관업무 경력자 우대전공 환경에너지공학과'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Arduino, Python, 라즈베리파이, PowerPoint, ESP32, 3D프린터, 인공지능', '핵심역량': '창의성, 협동심, 성장지향성, 적응성', '우대': '기본우일대 인근거주자'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Jira, Python, Pytorch, Tensorflow, Excel, Notion, Ethereum, GPT, Diffusion, LLM', '핵심역량': '성실성, 성취지향성, 성장지향성, 계획성, 꼼꼼함, 적응성', '우대': '외국어 [영어] TOEIC 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Docker, MariaDB, MySQL, PostgreSQL, Ai, LLM, liama, Lamba', '핵심역량': '성실성, 성장지향성, 꼼꼼함'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Docker, MariaDB, MySQL, PostgreSQL, Ai, LLM, liama, Lamba', '핵심역량': '성실성, 성장지향성, 꼼꼼함'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C#, C++'}
# {'경력': '신입', '학력': '대졸이상'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Python, ROS', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': ''}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Docker, Flask, kubernetes, Python, Pytorch, Tensorflow, CUDA, NLU, Fastapi', '핵심역량': '성취지향성, 창의성, 협동심', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '신입', '학력': '학력무관', '우대': '기본우일대 영어가능자 자격증 정보처리기사 우대전공 제어계측공학과'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, Pytorch', '우대': '기본우일대 영어가능자 자격증 정보처리기사 우대전공 제어계측공학과'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '핵심역량': '성실성, 꼼꼼함, 적응성, 계획성, 스트레스관리', '우대': '기본우일대 유관업무 경력자(3년)'}
# {'경력': '신입', '학력': '대졸이상', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Python, Tensorflow'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Consulting, modeling, Palantir, o9, SAP IBP', '핵심역량': '성취지향성, 창의성, 성장지향성'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'C#, WPF, VC++, Machine Vision', '핵심역량': '성실성, 창의성, 협동심, 성취지향성, 적응성, 계획성', '우대': '기본우일대 병역특례'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'C++, Git, Jira, Pytorch, Confluence, OCR, Github, GITLAB, Object Detection, NER', '핵심역량': '윤리의식, 창의성, 협동심, 적응성, 스트레스관리', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C, C#, C++, JAVA, OpenCV, Python', '우대': '기본우일대 인근거주자'}
# {'경력': '신입', '학력': '초대졸이상', '스킬': 'C, C#, C++, JAVA, OpenCV, Python', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'C, C#, C++, JAVA, OpenCV, Python', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'AWS, Git, JAVA, PostgreSQL, RestAPI, Spring Framework', '우대': '기본우일대 영어능통자(원어민수준)'}
# {'경력': '경력 (7년이상)', '학력': '대학원(석사)이상', '스킬': 'Android, API, C, C++, JAVA, Javascript, 임베디드리눅스, 임베디드 소프트웨어, 임베디드 하드웨어, Ai', '핵심역량': '계획성, 성실성, 성취지향성, 꼼꼼함, 적응성, 창의성, 성장지향성', '우대': '기본우일대 영어가능자 자격증 정보처리기사 우대전공 컴퓨터공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '신입', '학력': '대졸이상'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Python, SQL'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'API, JAVA, JSP, MySQL, Oracle, SQL'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': '', '핵심역량': '성실성, 적응성, 협동심, 꼼꼼함', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'Python, Pytorch, Tensorflow, Linux, Ai, 머신러닝, ChatGPT, 챗봇, 솔루션 개발, 프레임워크'}
# {'경력': '경력', '학력': '초대졸이상', '스킬': 'C#, Javascript, VB', '핵심역량': '계획성, 성실성, 꼼꼼함, 스트레스관리, 적응성, 창의성', '우대': '자격증 정보처리기사'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Hadoop, JAVA, Pandas, Python, Pytorch, Spark, SQL, Tensorflow, DL, Matplotlib', '핵심역량': '성취지향성, 꼼꼼함, 메타인지, 성실성, 적응성', '우대': '기본우일대 전산학에 대한 기본적인 이해도가 있는 분 자격증 정보처리기사 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C, C++, Pytorch, Scala, Tensorflow, F#, haskell, Optimizing ML, vision algorithm on DSP, vision algorithm on NPU'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'C, C++, Python', '핵심역량': '성실성, 꼼꼼함, 성장지향성, 계획성, 적응성, 협동심'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'Android, C, C++, Python', '핵심역량': '성실성, 협동심, 성장지향성, 적응성', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Python'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'Azure, React, VDI, Teams, Powershell, Exchange, microsoft 365, openAI, POWER PLATFORM, Microsoft Defender', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '대학원(석사)이상', '스킬': 'OpenCV, FFmpeg'}
# {'경력': '신입', '학력': '대학원(석사)이상', '스킬': 'C, Python, Linux'}
# {'경력': '경력', '학력': '초대졸이상', '스킬': '', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '신입', '학력': '대졸이상', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (4년이상)', '학력': '대졸이상', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '핵심역량': '성실성, 꼼꼼함, 협동심, 성장지향성, 계획성', '우대': '기본우일대 서비스로봇 제어개발 경력자'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '우대': '기본우일대 관련 학과 전공자 우대전공 기계공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '자격증 정보처리기사'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Python', '우대': '기본우일대 유관업무 경험자(인턴·알바) 자격증 정보처리기사'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Git, Javascript', '핵심역량': '성실성, 적응성, 성장지향성, 꼼꼼함', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '신입', '학력': '초대졸이상', '스킬': 'C#, HTML, JAVA, Python, VB'}
# {'경력': '경력 (5년이상)', '학력': '초대졸이상', '스킬': 'C#, HTML, JAVA, Python, VB'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'Pytorch, Tensorflow'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Hadoop, Spark, SQL, Linux'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Kafka, Keras, Python, Pytorch, Scipy, SQL, Tensorflow', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Python, 파이썬', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Python, Pytorch, R, Tensorflow, Bash, 데이터분석, Coding, 딥러닝, biomedical background, 영상데이터', '우대': '우대전공 의료공학과'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Git, Python, Pytorch, NLU, NLP', '우대': '기본우일대 영어가능자'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '신입', '학력': '학력무관', '우대': '기본우일대 차량소지자'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'AWS, C, C++, Python, Pytorch, Shell Script, Linux, CUDA', '우대': '기본우일대 관련 학과 전공자 우대전공 반도체공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'C, C#, C++, Qt', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C, C++, HMI, MFC, VIsualC·C++, Window', '우대': '기본우일대 국가유공자 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': '', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'API, AWS, CSS, Javascript, MSSQL', '핵심역량': '협동심, 성장지향성, 메타인지'}
# {'경력': '경력 (8년이상)', '학력': '학력무관', '스킬': 'ElasticStack, JAVA, Javascript, Spring, nodejs'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'AWS, Docker, Git, Python, Pytorch, RestAPI, Ubuntu, MachineLearning, Deeplearning, SSH', '핵심역량': '창의성, 성장지향성, 성실성, 협동심'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력 (5년이상)', '학력': '초대졸이상', '스킬': 'C#, HTML, JAVA, Python, VB'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Keras, Python, Pytorch, Tensorflow, CNN, CT, CUDA, DL, EMR, MRI', '핵심역량': '계획성, 성실성, 협동심, 성장지향성, 꼼꼼함', '우대': '기본우일대 관련 학과 전공자 우대전공 의료공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'JAVA, Jquery, Python, Spring, Tensorflow, Vue', '우대': '기본우일대 유관업무 경력자(5년) 자격증 정보처리기사 우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C, C++, Python, Pytorch, R, Numpy'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Azure, Keras, Python, Pytorch, React, Tensorflow, ETL, OCR, RPA, Langchain', '핵심역량': '계획성, 성실성, 협동심, 성장지향성, 성취지향성, 꼼꼼함'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'JAVA, Javascript, JSP, Node'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Python, Pytorch, SQL, Tensorflow, ETL, Nifi, Scikit-Learn', '핵심역량': '적응성, 협동심, 메타인지, 성실성', '우대': '우대전공 컴퓨터공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C, C++, Python, CNN, 데이터사이언스, RNN'}
# {'경력': '신입', '학력': '대졸이상'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C++, Docker, Python, Pytorch, Linux, GitHub, NLP, REST'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'GraphQL, TypeScript, Vue'}
# {'경력': '경력 (5년이상)', '학력': '대학원(석사)이상', '스킬': 'AWS, C++'}
# {'경력': '경력 (6년이상)', '학력': '대졸이상', '스킬': 'C, C++'}
# {'경력': '경력 (6년이상)', '학력': '대졸이상', '스킬': 'Pytorch, Tensorflow'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Pytorch, Tensorflow'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C, C++'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'Oracle, Python'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Keras, NoSQL, Python, Pytorch', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력', '학력': '초대졸이상', '우대': '기본우일대 영어능통자(원어민수준) 우대전공 산업공학과'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Python, Pytorch, SQL, Tensorflow', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '신입', '학력': '학력무관', '핵심역량': '꼼꼼함, 성장지향성, 성실성, 성취지향성'}
# {'경력': '경력 (2년이상)', '학력': '학력무관', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C#, C++, OpenCV, Python, Rust, Segment'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'API, HTML, JAVA, MySQL, Python, RpA, 인공지능, 머신러닝', '우대': '기본우일대 컴퓨터활용능력 우수자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'AWS, Docker, kubernetes, PostgreSQL, Python, Redis, GitHub, Fastapi, S3', '우대': '기본우일대 유관업무 경험자(인턴·알바) 우대전공 정보통신공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'OpenCV, Python, Pytorch, Tensorflow, HuggingFace, triton', '우대': '기본우일대 석사학위 수여자 우대전공 정보통신공학과'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Keras, Python, Pytorch, Tensorflow', '우대': '기본우일대 석사학위 수여자 우대전공 산업공학과'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'C, C++, Matlab, Python', '핵심역량': '계획성, 꼼꼼함, 성장지향성, 윤리의식, 성실성, 성취지향성'}
# {'경력': '경력 (8년이상)', '학력': '대졸이상', '스킬': 'JAVA, Javascript, Node', '핵심역량': '계획성, 성실성, 협동심, 성장지향성, 성취지향성, 꼼꼼함, 적응성'}
# {'경력': '경력 (6년이상)', '학력': '대졸이상', '스킬': 'C, C++, Python, Tensorflow, TypeScript', '핵심역량': '계획성, 적응성, 협동심, 성장지향성, 창의성, 성실성, 꼼꼼함'}
# {'경력': '경력 (10년이상)', '학력': '대졸이상', '스킬': 'JAVA, Javascript, Node', '핵심역량': '계획성, 협동심, 성장지향성, 성실성, 성취지향성, 꼼꼼함, 적응성, 창의성', '우대': '기본우일대 학점우수(대졸 4'}
# {'경력': '경력 (8년이상)', '학력': '대졸이상', '스킬': 'JAVA, Javascript, Node', '핵심역량': '계획성, 성실성, 협동심, 성장지향성, 성취지향성, 꼼꼼함, 적응성'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python', '우대': '기본우일대 관련 자격증 보유자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python', '우대': '기본우일대 석사학위 수여자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python', '우대': '기본우일대 관련 자격증 보유자 외국어 [영어] TOEIC 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '초대졸이상', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'Keras, Pandas, Python, Pytorch, Scipy, Tensorflow', '핵심역량': '계획성, 성실성, 창의성, 협동심, 윤리의식', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (5년이상)', '학력': '대학원(석사)이상', '스킬': 'Azure, C++, Pytorch, Tensorflow, GitHub, TensorRT, onnx, OpenVINO', '핵심역량': '창의성, 협동심, 성장지향성, 성실성, 성취지향성, 스트레스관리', '우대': '기본우일대 박사학위 수여자'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'OpenCV, Python, Pytorch, PyQt, GUI, JSON, 정보처리기사 자격', '핵심역량': '성실성, 꼼꼼함, 적응성, 협동심, 스트레스관리, 계획성', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Python, devops, ml'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'JAVA, Python, Pytorch, Shell Script', '핵심역량': '성실성, 메타인지, 자존감'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Git, Google Analytics, Keras, Pytorch, Tensorflow, LLM, Generative AI, RAG, prompt engineering'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Azure, Django, Docker, Flask, kubernetes, Python, Pytorch, Tensorflow, Cloud, Fastapi'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C, Python, Linux, 딥러닝, 임베디드, 알고리즘', '우대': '기본우일대 영어가능자'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상'}
# {'경력': '경력 (5년이상)', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'JAVA, OpenCV, Python, Pytorch, SQL, Tensorflow, CNN, 정보처리기사 자격, NLP, GPT', '핵심역량': '계획성, 성취지향성, 창의성, 성장지향성, 협동심, 꼼꼼함, 적응성, 성실성', '우대': '우대전공 응용소프트웨어공학과'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Pytorch, 임베디드리눅스, CUDA, C/C++', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력', '학력': '대졸이상', '우대': '우대전공 컴퓨터 소프트웨어'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Docker, Python, CNN, CUDA, GAN, GitHub', '핵심역량': '성실성, 창의성, 성장지향성, 계획성, 협동심, 성취지향성', '우대': '기본우일대 유관업무 경력자(1년)'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'C++, JAVA, Python'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 수어 글로스 전사경험 1년이상 자격증 수어통역사'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'C, C++, Python, Pytorch, Tensorflow, CUDA, LiDAR'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력 (8년이상)', '학력': '학력무관', '핵심역량': '성실성, 꼼꼼함, 협동심'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C, C++, Qt, Windows, macOS', '우대': '우대전공 컴퓨터공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'API, ASP', '핵심역량': '성실성, 윤리의식, 창의성, 협동심, 꼼꼼함, 계획성', '우대': '기본우일대 인근거주자 우대전공 전기전자공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C++, Python, Tensorflow, Numpy'}
# {'경력': '경력', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Arduino, AWS, Keras, Python, Tensorflow', '핵심역량': '성실성, 윤리의식, 창의성, 협동심, 꼼꼼함', '우대': '기본우일대 통계분석·리서치 능숙자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Python, Pytorch, SQL, Tensorflow, CNN, JSON', '핵심역량': '성실성, 협동심, 계획성, 적응성', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력 (10년이상)', '학력': '대학원(석사)이상', '우대': '기본우일대 영어가능자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'API, AWS, C#, Docker, JAVA, Keras, OpenCV, Python, Pytorch, Tensorflow', '핵심역량': '꼼꼼함, 계획성, 성장지향성, 성실성, 성취지향성, 적응성, 창의성, 협동심', '우대': '기본우일대 학점우수(대졸 4'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, Pytorch, Tensorflow, DL, ml', '우대': '기본우일대 자격증 : 정보처리기사'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'AWS, Azure, Python, Pytorch, Spark, SQL, Tensorflow'}
# {'경력': '경력 (1년이상)', '학력': '학력무관', '스킬': 'Docker, Python, Pytorch, Linux, GitHub'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C#, WPF', '핵심역량': '협동심, 성취지향성, 창의성', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'C, C++, Python'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Pytorch, NLP, yolo, 챗GPT', '핵심역량': '윤리의식, 적응성, 성장지향성, 메타인지, 성취지향성, 스트레스관리', '우대': '기본우일대 영어가능자 우대전공 정보통신공학과'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'C#, ECMAscript, Git, JAVA, Javascript, Kotlin, MongoDB, Node', '핵심역량': '성실성, 적응성, 협동심, 꼼꼼함', '우대': '기본우일대 학점우수(대졸 4'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Python', '우대': '기본우일대 유관업무 경험자(인턴·알바) 자격증 정보처리기사'}
# {'경력': '신입', '학력': '초대졸이상', '우대': '기본우일대 국가유공자 자격증 정보처리기사'}
# {'경력': '경력 6년이상', '학력': '대학원(석사)이상', '스킬': 'Docker, Flask, Python, RestAPI, Tensorflow, Ubuntu, Fastapi, Container, tytorch', '우대': '기본우일대 학점우수(대졸 4'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Hadoop, JAVA, Python, R, SQL, Tensorflow'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Hadoop, JAVA, Python, R, SQL, Tensorflow'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Tensorflow, Keras, Pythor', '우대': '기본우일대 영어가능자 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '대학원(석사)이상', '스킬': 'Python, SQL, ADsP 자격, CNN, 머신러닝, 프로그래밍, 인공지능, 딥러닝, 기계번역, 데이터 수집 및 정제'}
# {'경력': '경력 (5년이상)', '학력': '초대졸이상', '스킬': 'API, Docker, Git, JAVA, MariaDB, MySQL, OracleDB, Python, Spring, SQL', '핵심역량': '꼼꼼함, 협동심, 성장지향성, 적응성, 계획성', '우대': '기본우일대 인근거주자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': '', '핵심역량': '성실성, 창의성, 협동심, 성장지향성, 계획성, 성취지향성, 꼼꼼함, 윤리의식, 자존감, 적응성', '우대': '기본우일대 인근거주자'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Docker, Swift, 영어, 영어회화, gRPC, MQ, WebSocket, 기계학습, Apache Kafka, Kubernetix', '우대': '기본우일대 영어가능자'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'ElasticStack, JAVA, Javascript, Spring, nodejs'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'ElasticStack, JAVA, Javascript, Spring, nodejs'}
# {'경력': '경력 (3년이상)', '학력': '학력무관'}
# {'경력': '경력', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'Python, Pytorch', '핵심역량': '성실성, 성취지향성, 성장지향성, 계획성, 꼼꼼함', '우대': '기본우일대 영어가능자 외국어 [영어] TOEIC'}
# {'경력': '신입', '학력': '초대졸이상', '스킬': 'Hadoop, JAVA, Python, Scala, SQL, Hive, Airflow, Apache Flume, Apache Impala, AWS Redshift', '핵심역량': '계획성, 창의성, 성실성, 성취지향성, 꼼꼼함, 윤리의식'}
# {'경력': '경력', '학력': '초대졸이상', '스킬': 'JAVA', '핵심역량': '계획성, 꼼꼼함, 적응성, 협동심', '우대': '기본우일대 관련 학과 전공자 자격증 정보처리산업기사'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C#, C++, MFC, Python, Pytorch, Tensorflow', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'C#, OpenCV, Python, NLP, yolo', '핵심역량': '계획성, 성실성, 협동심, 스트레스관리, 자존감', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '초대졸이상'}
# {'경력': '경력', '학력': '대학원(석사)이상', '우대': '기본우일대 인근거주자'}
# {'경력': '신입', '학력': '대졸이상', '우대': '기본우일대 유관업무 경력자 우대전공 전기전자공학과'}
# {'경력': '경력', '학력': '초대졸이상 (졸업예정자 가능)', '스킬': 'C#, Python, VIsualC·C++', '핵심역량': '꼼꼼함, 적응성, 협동심, 메타인지, 성장지향성, 스트레스관리, 계획성, 성실성', '우대': '기본우일대 공모전 입상자 자격증 정보처리기사 우대전공 제어계측공학과'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Python, ROS', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C# JAVA, 모델러 ( 반도체, 디스플레이 공정 경험자), 통계분석경험자, EES 경험자'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'JAVA, Keras, MariaDB, Pytorch, Tensorflow, 전자정부표준프레임워크', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '대졸이상', '스킬': 'Python, Pytorch, Ai, 최적화'}
# {'경력': '경력 (2년이상)', '학력': '학력무관', '스킬': 'OpenCV, Pytorch, Tensorflow, Scikit-Learn', '우대': '기본우일대 컴퓨터공학, 인공지능 및 인접 분야 전공(석사 이상)이나 경력을 보유한 분(3년 이상)'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Docker, Kafka, Logstash, Pandas, Python, Pytorch, Tensorflow, Linux, Elasticsearch', '핵심역량': '계획성, 성장지향성, 협동심', '우대': '기본우일대 영어가능자 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'AR, Python, Unity, 영상처리, 인공지능, opencv', '핵심역량': '창의성, 성장지향성, 적응성'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '핵심역량': '성취지향성, 창의성, 메타인지, 성장지향성, 꼼꼼함, 계획성, 성실성', '우대': '기본우일대 영어가능자'}
# {'경력': '신입', '학력': '학력무관', '핵심역량': '계획성, 성실성, 성장지향성, 성취지향성, 협동심', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': '', '우대': '기본우일대 국가유공자 우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C#, C++, MFC, OpenCV, Euresys 라이브러리 사용 가능자', '우대': '기본우일대 영어가능자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C, C++, Linux'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, R', '우대': '기본우일대 공모전 입상자 우대전공 통계학과'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'Python, Github, GPT', '핵심역량': '성실성, 협동심, 성취지향성'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C#, C++, Visual Studio, Linux', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'C, C#, C++, OpenCV, Python, Halcon, Mil', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'AWS, Azure, Docker, GCP, kubernetes, NoSQL, Python, RDBMS, Scala, Spark', '핵심역량': '계획성, 성실성, 협동심, 성장지향성', '우대': '우대전공 컴퓨터공학과'}
# {'경력': '경력 (1년이상)', '학력': '대학원(석사)이상', '스킬': 'C++, Python, Pytorch, Tensorflow'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'Pytorch, Tensorflow'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'AWS, Azure, GCP, kubernetes, Linux'}
# {'경력': '경력 (1년이상)', '학력': '초대졸이상', '스킬': 'C#, C++, OpenCV, Python, R, Rust'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Flutter, OpenCV, Python, Scipy, Tensorflow, Nginx, Numpy, fast-api, tkinter&PyQt'}
# {'경력': '경력 직무별 상이', '학력': '대졸이상 직무별 상이', '스킬': 'C++, Git, JAVA, Jira, Jquery, NoSQL, Pytorch, RDBMS, React, Spring Boot, Tensorflow, Vue', '핵심역량': '계획성, 성실성, 꼼꼼함', '우대': '기본우일대 영어가능자 자격증 정보처리기사'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 유관업무 경력자(3년)'}
# {'경력': '경력 (3년이상)', '학력': '학력무관', '스킬': 'C#, C++, GoLang, Python, Ai, 머신러닝, 딥러닝', '핵심역량': '계획성, 꼼꼼함, 성장지향성, 적응성, 창의성', '우대': '기본우일대 유관업무 경험자(인턴·알바)'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '우대': '기본우일대 영어가능자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'ArcGIS, CSS, HTML, JAVA, Javascript, Python, QGIS, PowerPoint, OA, 컴퓨터활용능력', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '대학원(석사)이상'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Python, Pytorch, Tensorflow'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상', '스킬': 'C, C++, OpenCV', '핵심역량': '계획성, 성실성, 협동심, 꼼꼼함, 윤리의식', '우대': '기본우일대 병역특례'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 인근거주자 자격증 컴퓨터시스템응용기술사'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력 (3년이상)', '학력': '대학원(석사)이상'}
# {'경력': '경력', '학력': '학력무관', '우대': '자격증 정보처리기사'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Hadoop, SQL, BigQuery, DBMS, JSON, 정보처리기사 자격', '우대': '기본우일대 문서작성 우수자'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'Python, Pytorch, Tensorflow, Scikit-Learn', '우대': '기본우일대 문서작성 우수자'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'API, AWS, Docker, Git, JAVA, JPA, MariaDB, MongoDB, MSA'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'API, AWS, Docker, Git, JAVA, JPA, MariaDB, MongoDB, MSA'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'JAVA, Matlab, Python, SQL', '핵심역량': '계획성, 성실성, 창의성', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Python, Pytorch, Tensorflow, Lightning'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C++, Python, Pytorch, Tensorflow, Tableau', '핵심역량': '성실성, 적응성, 계획성, 꼼꼼함', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'AWS, Docker, Spring Boot, Notion, GitHub, 머신러닝, React', '핵심역량': '계획성, 협동심, 성장지향성, 성실성, 꼼꼼함'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'CSS, Django, Flask, HTML, PostgreSQL, Python, Fastapi, LLM', '핵심역량': '협동심, 성장지향성, 성실성, 창의성', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력 (3년이상)', '학력': '초대졸이상', '스킬': 'Azure, GCP, Javascript, PostgreSQL, Python, AWS EKS, BigQuery, Bitbucket', '핵심역량': '협동심, 성장지향성, 성실성, 창의성', '우대': '기본우일대 관련 학과 전공자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C++, OpenCV, Python, DL'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'Ajax, C, C#, C++, HTML, JSP, Python, SQL, Tensorflow', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '대졸이상', '우대': '우대전공 컴퓨터 소프트웨어'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'C++, Python', '우대': '기본우일대 석사학위 수여자 자격증 정보처리기사 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '대졸이상', '핵심역량': '꼼꼼함, 성장지향성, 성실성, 성취지향성'}
# {'경력': '신입', '학력': '대학원(석사)이상', '스킬': 'C, C#, C++, JAVA, Python, C++Builder'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Keras, Python, Pytorch, Tensorflow, NAS, network compression'}
# {'경력': '신입', '학력': '대졸이상'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Hadoop, Kafka, NoSQL, Python, R, Spark, Nifi, MML, 생성 AI', '우대': '기본우일대 영어가능자 자격증 정보처리기사 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, R', '우대': '기본우일대 유관업무 경험자(인턴·알바) 자격증 정보보안기사 우대전공 컴퓨터공학과'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Python, Fortran', '핵심역량': '협동심, 성장지향성, 적응성', '우대': '우대전공 컴퓨터공학과'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'C#, C++, 영어회화, 1종보통운전면허, 2종보통운전면허, 운전면허, 컴퓨터활용능력', '핵심역량': '계획성, 성실성, 꼼꼼함, 적응성, 창의성, 협동심', '우대': '기본우일대 영어가능자'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C, C++, 임베디드리눅스, Linux Application, bsp kernel', '우대': '기본우일대 컴퓨터활용능력 우수자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (5년이상)', '학력': '학력무관'}
# {'경력': '경력', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'JAVA, Node'}
# {'경력': '경력 (2년이상)', '학력': '초대졸이상', '스킬': 'Python, Window, Linux', '우대': '기본우일대 컴퓨터활용능력 우수자 자격증 정보처리기사 우대전공 컴퓨터공학과'}
# {'경력': '신입', '학력': '대졸이상', '스킬': 'C#, C++, MFC, OpenCV, Qt, Halcon, Mil', '우대': '기본우일대 영상처리 라이브러리(OpenCV, MIL, Halcon 등)를 활용한 SW 개발 유경험자'}
# {'경력': '경력', '학력': '대학원(석사)이상 (졸업예정자 가능)', '스킬': 'C, C++, Pytorch', '우대': '기본우일대 석사학위 수여자 우대전공 컴퓨터공학과'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상', '스킬': 'Javascript, React, TypeScript, Webpack, styled-components, vite, 인공지능, React Query, Ant Design', '우대': '기본우일대 인근거주자'}
# {'경력': '경력 (4년이상)', '학력': '초대졸이상', '우대': '기본우일대 즉시출근 가능자'}
# {'경력': '경력 (4년이상)', '학력': '대졸이상', '스킬': 'Hadoop, Keras, MongoDB, NoSQL, Python, Pytorch, SQL, Tensorflow, Apache Cassandra', '우대': '우대전공 정보통신공학과'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Flutter, JAVA, Oracle, Python, React, TypeScript, Figma, Next', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (2년이상)', '학력': '대졸이상'}
# {'경력': '경력 (2년이상)', '학력': '대학원(석사)이상'}
# {'경력': '경력 (5년이상)', '학력': '대학원(박사)이상'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'Keras, Python, Pytorch, Tensorflow, 라즈베리파이'}
# {'경력': '경력', '학력': '학력무관', '스킬': '일본어', '우대': '기본우일대 일본어가능자'}
# {'경력': '신입', '학력': '대졸이상'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '경력'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Bootstrap, CSS3, Git, HTML, JAVA, Javascript, Jquery, JSP, MySQL, Pandas, Python, React, Servlet, Spring, ERP, 무역영어, GitHub, Matplotlib, Numpy, 국제무역사 자격', '핵심역량': '계획성, 성취지향성, 꼼꼼함'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력'}
# {'경력': '신입', '학력': '학력무관', '핵심역량': '계획성, 꼼꼼함, 성실성'}
# {'경력': '신입', '학력': '고졸이상', '스킬': 'AWS, Git, Hadoop, JAVA, MyBatis, MySQL, OracleDB, Python, Spring, Spring Boot'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '초대졸이상'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '신입', '학력': '대학원(석사)이상'}
# {'경력': '경력', '학력': '대학원(석사)이상'}
# {'경력': '경력', '학력': '대학원(석사)이상'}
# {'경력': '신입', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Python, UI, UX, 기업 교육, 디지털 교육', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'Android, C#, HMI, JPA, OpenCV, Spring, SQL, ARM, AVR, JSTL, JWT, PLC, JUnit, IoT, 임베디드 시스템, 웹서버, alot, 인텔엣지', '핵심역량': '계획성, 성취지향성, 꼼꼼함'}
# {'경력': '경력', '학력': '대졸이상'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Ajax, CSS, HMI, HTML, JAVA, Javascript, JSP, MySQL, Oracle, SQL, 어셈블리'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '신입', '학력': '대학원(석사)이상 (졸업예정자 가능)'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '스킬': 'Jira, Figma, Amplitude, AppsFlyer, GTM, GA, powerBI', '핵심역량': '성실성, 적응성, 계획성, 꼼꼼함', '우대': '기본우일대 장애인 자격증 NCS(인공지능) 강사 우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 유관업무 경력자'}
# {'경력': '경력 (7년이상)', '학력': '대졸이상', '스킬': 'C, C++'}
# {'경력': '경력', '학력': '초대졸이상'}
# {'경력': '경력', '학력': '학력무관', '우대': '기본우일대 인근거주자'}
# {'경력': '신입', '학력': '대졸이상 (졸업예정자 가능)', '스킬': 'C#, C++, OpenCV, Python'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': '의사소통, 문제해결', '우대': '기본우일대 개발역량 보유(LLM, 랭체인 등 기본개념이해)'}
# {'경력': '경력', '학력': '초대졸이상', '우대': '우대전공 컴퓨터공학과'}
# {'경력': '경력 (2년이상)', '학력': '학력무관', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (10년이상)', '학력': '학력무관', '스킬': 'Python'}
# {'경력': '경력 (7년이상)', '학력': '학력무관', '스킬': 'Ai, 챗봇, 데이터 전처리, 프롬프트 엔지니어'}
# {'경력': '경력', '학력': '고졸이상', '스킬': 'Excel, OA', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (10년이상)', '학력': '대졸이상', '스킬': '', '우대': '우대전공 정보통신공학과'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '신입', '학력': '학력무관', '스킬': 'JAVA, 디버깅'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Google Analytics, JAVA, Python, Spring, RPA', '핵심역량': '성실성, 적응성, 협동심, 성장지향성, 윤리의식, 계획성'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'RPA, LowCode, Chat GPT4, outsystems', '핵심역량': '성실성, 적응성, 협동심, 성장지향성, 윤리의식, 계획성'}
# {'경력': '신입', '학력': '초대졸이상'}
# {'경력': '경력', '학력': '고졸이상 (졸업예정자 가능)', '스킬': '일본어, JLPT, JPT', '핵심역량': '계획성, 성취지향성, 꼼꼼함', '우대': '자격증 JLPT N2 우대전공 일본어일본학과'}
# {'경력': '경력', '학력': '학력무관'}
# {'경력': '경력', '학력': '학력무관', '스킬': 'Excel, 구글 스프레드시트', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (5년이상)', '학력': '학력무관', '스킬': 'JAVA, Javascript, Python, React, RestAPI, Cloud, GUI, 백엔드, 프론트엔드, 챗봇', '우대': '기본우일대 관련 학과 전공자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '스킬': 'NoSQL, Python, Pytorch, Tensorflow, Cloud, NLU, NLP, LLM, Langchain, LlamaIndex', '우대': '기본우일대 석사학위 수여자'}
# {'경력': '경력 (3년이상)', '학력': '대졸이상', '우대': '기본우일대 컴퓨터활용능력 우수자'}
# {'경력': '경력 (5년이상)', '학력': '대졸이상', '핵심역량': '창의성, 협동심, 성장지향성, 계획성', '우대': '기본우일대 유관업무 경력자 우대전공 기계공학과'}
# {'경력': '신입', '학력': '학력무관'}
# ['신입', '신입', '경력 (3년이상)', '경력 (3년이상)', '경력 (3년이상)']
# ['대졸이상', '대학원(석사)이상', '대졸이상', '학력무관', '대졸이상']
# [nan, nan, '성실성, 성취지향성, 협동심, 성장지향성, 적응성', nan, '꼼꼼함, 협동심, 계획성']
# ['Django, Flutter, MongoDB, MySQL, Python, React, TypeScript, Jotai, Langchain', nan, 'Python, Pytorch, Tensorflow, Scikit-Learn', 'JAVA, Unix, Window, Linux, 클라우드, 정보보안, 인프라, 보안컨설팅, 데이터, it개발', 'API, AWS, GCP, PostgreSQL, Python, RestAPI, Vuex, Opensearch, Langchain, Qdrant']

# %%
##

apply_500_DF = pd.DataFrame( {'기업명': raw['comp_name'].to_list(), '경력':period, '학력':degree, '핵심역량':utility, '스킬':skill})
apply_500_DF.head(5)
# Out:
#          기업명            경력           학력             핵심역량  \
# 0     현대자동차㈜            경력         학력무관    계획성, 성실성, 꼼꼼함
# 1     ㈜아이엠뱅크  경력 직무에 따라 상이         학력무관  성실성, 성취지향성, 계획성
# 2      ㈜세종교육            신입  학력무관 교육별 상이              NaN
# 3      GS리테일     경력 (3년이상)         대졸이상  계획성, 성취지향성, 꼼꼼함
# 4  (주)우아한형제들            신입         학력무관              NaN
#
#                                                   스킬
# 0                                                NaN
# 1                                                NaN
# 2  Hadoop, JAVA, Python, Tensorflow, Tableau, ERP...
# 3              API, AWS, GCP, kubernetes, Python, Go
# 4                                      ASP, API, ASP

# %%
# 저장
apply_500_DF.to_csv('apply_info_500.csv', index=False, encoding='utf-8-sig')
# apply_500_DF.to_excel('apply_info_500_excel.excel',index=False)

# %% [markdown]
# #### 핵심역량 & 스킬 워드클라우드

# %%
# 내용 .txt 파일로 저장

# apply_500_DF['스킬'][~apply_500_DF['스킬'].isna()].to_list()
# apply_500_DF['스킬'][~apply_500_DF['스킬'].isna()].to_list()
# Out:
# ['Hadoop, JAVA, Python, Tensorflow, Tableau, ERP, MES, PLC',
#  'API, AWS, GCP, kubernetes, Python, Go',
#  'ASP, API, ASP',
#  '',
#  'Pytorch, Tensorflow, Linux, CAD, BSP, MCU, Micom, RTOS',
#  'AWS, Hadoop, JAVA, Javascript, Kafka, Kotlin, OpenGL, Scala, Swift, Spring Framework',
#  'Ai, LLM',
#  'AWS, Azure, GCP, MySQL, NoSQL, SQL, Tensorflow, Linux',
#  'JAVA, Python',
#  'Ai',
#  'JAVA, MySQL, Oracle, PHP, Python, Illustrator, Photoshop, 파이널컷, 프리미어, 영어',
#  '무선설비기사 자격, 운전면허, 전자기기기능사 자격, 정보기기운용기능사 자격, 정보보안기사 자격, 정보처리기능사 자격, 정보처리기사 자격, 정보처리산업기사 자격, 정보통신기사 자격, 토목기사 자격, 토목산업기사 자격',
#  'AWS, Git, GraphQL, Keras, MariaDB, MongoDB, Node',
#  'API, JAVA, Python',
#  'Docker, Hadoop, JAVA, Kafka, kubernetes, PostgreSQL, Python, Spark',
#  'MSSQL, Python, SQL',
#  'AWS, Python, Pytorch, Tensorflow, AWS EKS',
#  'C, C#, C++, HTML, iOS, JAVA, Javascript, Window, Linux, Cloud',
#  'C#, C++, MSSQL, OpenCV, Oracle, Pytorch, CIM, RTD, mcs',
#  'C, C#, C++, Visual Studio, VIsualC·C++, C++Builder',
#  '',
#  'Python, Pytorch, RestAPI, Tensorflow, Restful API',
#  'Python',
#  'Android, C#, Flutter, iOS, JAVA, Javascript, JSP, NoSQL, Oracle, Python, React, Spring, Vue',
#  'Python',
#  'JAVA, Python, React, OCR, NLP, LLM, RAG',
#  'C, C#, C++, OpenCV',
#  'C, C++, Docker, Git, OpenGL, Python, Pytorch, Qt, Tensorflow, Verilog, Linux, Excel, OrCAD, 영어회화, DSP, MCU, Microsoft Office, PADs, UVM, WebSocket',
#  '주요',
#  'API, Azure, JAVA, Node',
#  'JAVA, JSP',
#  'Docker, JAVA, Kafka, kubernetes, MySQL, Python, Pytorch, Tensorflow, Spring Framework, RDB',
#  'C, C++, Python',
#  'C, C#, C++, MFC, VIsualC·C++',
#  'C, C++, JAVA, Javascript, Python, Pytorch, Swift, DL, 임베디드 소프트웨어, 임베디드 하드웨어',
#  'C, C++, MSSQL, SAP, DBMS, 컨설팅, SW, 솔루션',
#  'C, C++, Git, Python, Pytorch, Linux, CUDA, Scikit-Learn, FFmpeg',
#  'Python, C/C++, COMPUTER VISION, Machine Learning, Image processing',
#  'API, AWS, ElasticStack, Python, RDBMS, Spark, SQL',
#  'C++, Git, Matlab, Python, Solidworks, 임베디드리눅스, AutoCAD, ROS, ROS2, Simulink',
#  'Python, SAS, SQL',
#  'C, C++, JAVA',
#  'C, C++, JAVA',
#  'AWS, Django, Docker, Hadoop, MongoDB, PostgreSQL, Python, ELK',
#  'Django, Flutter, MongoDB, MySQL, Python, React, TypeScript, Jotai, Langchain',
#  'Python, Pytorch, Tensorflow, Scikit-Learn',
#  'JAVA, Unix, Window, Linux, 클라우드, 정보보안, 인프라, 보안컨설팅, 데이터, it개발',
#  'API, AWS, GCP, PostgreSQL, Python, RestAPI, Vuex, Opensearch, Langchain, Qdrant',
#  'Python, Pytorch',
#  'Docker, Flask, kubernetes, Matlab, Python, Pytorch, R, Tensorflow',
#  'C++, Matlab, Python',
#  'Pytorch, Tensorflow',
#  'Python, NLP, LLM, RAG',
#  'C++, VisualBasic, VIsualC·C++',
#  'Python',
#  'JAVA, Keras, MariaDB, Pytorch, Tensorflow, 전자정부표준프레임워크',
#  'C, C++, Python',
#  'Git, Matlab, Pandas, Python, Pytorch, Scipy, Tensorflow, DL, Matplotlib, Numpy',
#  'MSSQL, MySQL, Python, R, SQL',
#  'JAVA, Javascript, Python, Spring, SQL',
#  'C#, C++, MariaDB, OpenCV, WPF, DBMS, MVVM, TCP/IP, HTTP, MQTT',
#  'JAVA, Kafka, Logstash, Python, SQL, Elasticsearch, Airflow, BigQuery, JSON, Kibana',
#  '',
#  'Python, Pytorch',
#  'Window, Linux, TCP/IP, VLAN',
#  'Hadoop, Oracle, Spark, Tensorflow, Window, Linux',
#  'Python, Tensorflow, CNN',
#  'OpenCV, Python, Pytorch, R, Tensorflow',
#  'AWS, CSS, Django, Flask, HTML, Javascript, Python',
#  'C, Matlab, Perl, Python, Verilog, System Verilog, 영어, 일본어, 중국어, Cadence, Microsoft Office, OPIc, TOEIC, TOEIC Speaking, UVM, 임베디드 소프트웨어',
#  'C, C#, C++, MFC, OpenCV, 머신러닝, 딥러닝, 이미지 프로세싱',
#  'C#, Directx, WPF, Halcon, Euresys',
#  'C#, Directx, WPF, Halcon, Euresys',
#  'Git, Python, Pytorch, Tensorflow, Unix, Linux',
#  'Python',
#  'Keras, Python, Pytorch, Tensorflow',
#  'Docker, Python, Pytorch, CNN, DL, GitHub, GitLab',
#  'Python, RDBMS, SQL, ERP, DBMS, NLP',
#  'C++, OpenCV, Python, Tensorflow, PyQt',
#  'SQL',
#  'C, C++',
#  'C, C++',
#  '',
#  'Docker, kubernetes, Python, Linux, DL, Ai, ml, LLM, RAG',
#  'Pandas, Python, Pytorch, Airflow, Langchain',
#  '3D, COMPUTER VISION, VSLAM',
#  'NLU, NLP, LLM, NLG',
#  'C, C++, Git, Python, Pytorch, Tensorflow, DL, ml',
#  'C, C++, Git, Python, Pytorch, Tensorflow, DL, ml',
#  'C, C++, Git, Python, ml, Embedded',
#  'C, C++, Git, Python, ml, Embedded',
#  'LLM, SLLM',
#  'LLM, SLLM',
#  'C++, Python, Tensorflow, Ubuntu, 영상처리, 딥러닝, 임베디드',
#  'C, C++, Git, Python, Ai, ml',
#  'C, C++, Git, Python, Ai, ml',
#  'C++, Python, Tensorflow, Ubuntu, 영상처리, 딥러닝, 임베디드, RDB, 웹 프론트',
#  'Python, RDBMS, SQL, ERP, DBMS, NLP',
#  'AWS, Django, Git, Hadoop, MariaDB, MySQL, NoSQL, Python, Spark, Linux',
#  'API, CSS3, Git, HTML5, Javascript, Vue',
#  'AWS, JAVA, JPA, MariaDB, MyBatis, MySQL, Spring Boot, Linux, Restful API, ChatGPT',
#  'API, C++, Django, MariaDB, MySQL, NoSQL, Python, bigdata, ChatGPT',
#  'CSS3, HTML5, Adobe XD, Figma, Illustrator, Photoshop, UI, UX, D3',
#  'Python, C/C++',
#  'C++, Python, Pytorch, Tensorflow, ROS, SLAM, SVM, 자율주행, RMS',
#  'C++, Python, Pytorch, Tensorflow, 영상처리',
#  'AWS, Pytorch, Tensorflow',
#  'C, C++, Python',
#  'Hadoop, Spark, SQL, Linux',
#  'Pytorch, Tensorflow',
#  'Python, Pytorch, Spark, Tensorflow',
#  'JAVA, kubernetes, OpenCV, Python, Pytorch, RDBMS, Vision',
#  'JAVA, MySQL, PHP, Python, SQL',
#  'OpenCV, Python, Pytorch, Matplotlib, Seaborn, plotly',
#  'C#, C++',
#  'C, C#, C++, MFC, OpenCV, 머신러닝, 딥러닝, 이미지 프로세싱',
#  'Arduino, Python, 라즈베리파이, PowerPoint, ESP32, 3D프린터, 인공지능',
#  'Jira, Python, Pytorch, Tensorflow, Excel, Notion, Ethereum, GPT, Diffusion, LLM',
#  'Docker, MariaDB, MySQL, PostgreSQL, Ai, LLM, liama, Lamba',
#  'Docker, MariaDB, MySQL, PostgreSQL, Ai, LLM, liama, Lamba',
#  'C, C#, C++',
#  'Python, ROS',
#  '',
#  'Docker, Flask, kubernetes, Python, Pytorch, Tensorflow, CUDA, NLU, Fastapi',
#  'Python, Pytorch',
#  'Python, Tensorflow',
#  'Consulting, modeling, Palantir, o9, SAP IBP',
#  'C#, WPF, VC++, Machine Vision',
#  'C++, Git, Jira, Pytorch, Confluence, OCR, Github, GITLAB, Object Detection, NER',
#  'C, C#, C++, JAVA, OpenCV, Python',
#  'C, C#, C++, JAVA, OpenCV, Python',
#  'C, C#, C++, JAVA, OpenCV, Python',
#  'AWS, Git, JAVA, PostgreSQL, RestAPI, Spring Framework',
#  'Android, API, C, C++, JAVA, Javascript, 임베디드리눅스, 임베디드 소프트웨어, 임베디드 하드웨어, Ai',
#  'Python, SQL',
#  'API, JAVA, JSP, MySQL, Oracle, SQL',
#  '',
#  'Python, Pytorch, Tensorflow, Linux, Ai, 머신러닝, ChatGPT, 챗봇, 솔루션 개발, 프레임워크',
#  'C#, Javascript, VB',
#  'Hadoop, JAVA, Pandas, Python, Pytorch, Spark, SQL, Tensorflow, DL, Matplotlib',
#  'C, C++, Pytorch, Scala, Tensorflow, F#, haskell, Optimizing ML, vision algorithm on DSP, vision algorithm on NPU',
#  'C, C++, Python',
#  'Android, C, C++, Python',
#  'Python',
#  'Azure, React, VDI, Teams, Powershell, Exchange, microsoft 365, openAI, POWER PLATFORM, Microsoft Defender',
#  'OpenCV, FFmpeg',
#  'C, Python, Linux',
#  '',
#  'Python',
#  'Git, Javascript',
#  'C#, HTML, JAVA, Python, VB',
#  'C#, HTML, JAVA, Python, VB',
#  'Pytorch, Tensorflow',
#  'Hadoop, Spark, SQL, Linux',
#  'Kafka, Keras, Python, Pytorch, Scipy, SQL, Tensorflow',
#  'Python, 파이썬',
#  'Python, Pytorch, R, Tensorflow, Bash, 데이터분석, Coding, 딥러닝, biomedical background, 영상데이터',
#  'Git, Python, Pytorch, NLU, NLP',
#  'AWS, C, C++, Python, Pytorch, Shell Script, Linux, CUDA',
#  'C, C#, C++, Qt',
#  'C, C++, HMI, MFC, VIsualC·C++, Window',
#  '',
#  'API, AWS, CSS, Javascript, MSSQL',
#  'ElasticStack, JAVA, Javascript, Spring, nodejs',
#  'AWS, Docker, Git, Python, Pytorch, RestAPI, Ubuntu, MachineLearning, Deeplearning, SSH',
#  'C#, HTML, JAVA, Python, VB',
#  'Keras, Python, Pytorch, Tensorflow, CNN, CT, CUDA, DL, EMR, MRI',
#  'JAVA, Jquery, Python, Spring, Tensorflow, Vue',
#  'C, C++, Python, Pytorch, R, Numpy',
#  'Azure, Keras, Python, Pytorch, React, Tensorflow, ETL, OCR, RPA, Langchain',
#  'JAVA, Javascript, JSP, Node',
#  'Python, Pytorch, SQL, Tensorflow, ETL, Nifi, Scikit-Learn',
#  'C, C++, Python, CNN, 데이터사이언스, RNN',
#  'C++, Docker, Python, Pytorch, Linux, GitHub, NLP, REST',
#  'GraphQL, TypeScript, Vue',
#  'AWS, C++',
#  'C, C++',
#  'Pytorch, Tensorflow',
#  'Pytorch, Tensorflow',
#  'C, C++',
#  'Oracle, Python',
#  'Keras, NoSQL, Python, Pytorch',
#  'Python, Pytorch, SQL, Tensorflow',
#  'C#, C++, OpenCV, Python, Rust, Segment',
#  'API, HTML, JAVA, MySQL, Python, RpA, 인공지능, 머신러닝',
#  'AWS, Docker, kubernetes, PostgreSQL, Python, Redis, GitHub, Fastapi, S3',
#  'OpenCV, Python, Pytorch, Tensorflow, HuggingFace, triton',
#  'Keras, Python, Pytorch, Tensorflow',
#  'C, C++, Matlab, Python',
#  'JAVA, Javascript, Node',
#  'C, C++, Python, Tensorflow, TypeScript',
#  'JAVA, Javascript, Node',
#  'JAVA, Javascript, Node',
#  'Python',
#  'Python',
#  'Python',
#  'Keras, Pandas, Python, Pytorch, Scipy, Tensorflow',
#  'Azure, C++, Pytorch, Tensorflow, GitHub, TensorRT, onnx, OpenVINO',
#  'OpenCV, Python, Pytorch, PyQt, GUI, JSON, 정보처리기사 자격',
#  'Python, devops, ml',
#  'JAVA, Python, Pytorch, Shell Script',
#  'Git, Google Analytics, Keras, Pytorch, Tensorflow, LLM, Generative AI, RAG, prompt engineering',
#  'Azure, Django, Docker, Flask, kubernetes, Python, Pytorch, Tensorflow, Cloud, Fastapi',
#  'C, Python, Linux, 딥러닝, 임베디드, 알고리즘',
#  'JAVA, OpenCV, Python, Pytorch, SQL, Tensorflow, CNN, 정보처리기사 자격, NLP, GPT',
#  'Pytorch, 임베디드리눅스, CUDA, C/C++',
#  'Docker, Python, CNN, CUDA, GAN, GitHub',
#  'C++, JAVA, Python',
#  'C, C++, Python, Pytorch, Tensorflow, CUDA, LiDAR',
#  'C, C++, Qt, Windows, macOS',
#  'API, ASP',
#  'C++, Python, Tensorflow, Numpy',
#  'Arduino, AWS, Keras, Python, Tensorflow',
#  'Python, Pytorch, SQL, Tensorflow, CNN, JSON',
#  'API, AWS, C#, Docker, JAVA, Keras, OpenCV, Python, Pytorch, Tensorflow',
#  'Python, Pytorch, Tensorflow, DL, ml',
#  'AWS, Azure, Python, Pytorch, Spark, SQL, Tensorflow',
#  'Docker, Python, Pytorch, Linux, GitHub',
#  'C#, WPF',
#  'C, C++, Python',
#  'Pytorch, NLP, yolo, 챗GPT',
#  'C#, ECMAscript, Git, JAVA, Javascript, Kotlin, MongoDB, Node',
#  'Python',
#  'Docker, Flask, Python, RestAPI, Tensorflow, Ubuntu, Fastapi, Container, tytorch',
#  'Hadoop, JAVA, Python, R, SQL, Tensorflow',
#  'Hadoop, JAVA, Python, R, SQL, Tensorflow',
#  'Tensorflow, Keras, Pythor',
#  'Python, SQL, ADsP 자격, CNN, 머신러닝, 프로그래밍, 인공지능, 딥러닝, 기계번역, 데이터 수집 및 정제',
#  'API, Docker, Git, JAVA, MariaDB, MySQL, OracleDB, Python, Spring, SQL',
#  '',
#  'Docker, Swift, 영어, 영어회화, gRPC, MQ, WebSocket, 기계학습, Apache Kafka, Kubernetix',
#  'ElasticStack, JAVA, Javascript, Spring, nodejs',
#  'ElasticStack, JAVA, Javascript, Spring, nodejs',
#  'Python, Pytorch',
#  'Hadoop, JAVA, Python, Scala, SQL, Hive, Airflow, Apache Flume, Apache Impala, AWS Redshift',
#  'JAVA',
#  'C#, C++, MFC, Python, Pytorch, Tensorflow',
#  'C#, OpenCV, Python, NLP, yolo',
#  'C#, Python, VIsualC·C++',
#  'Python, ROS',
#  'C# JAVA, 모델러 ( 반도체, 디스플레이 공정 경험자), 통계분석경험자, EES 경험자',
#  'JAVA, Keras, MariaDB, Pytorch, Tensorflow, 전자정부표준프레임워크',
#  'Python, Pytorch, Ai, 최적화',
#  'OpenCV, Pytorch, Tensorflow, Scikit-Learn',
#  'Docker, Kafka, Logstash, Pandas, Python, Pytorch, Tensorflow, Linux, Elasticsearch',
#  'AR, Python, Unity, 영상처리, 인공지능, opencv',
#  '',
#  'C#, C++, MFC, OpenCV, Euresys 라이브러리 사용 가능자',
#  'C, C++, Linux',
#  'Python, R',
#  'Python, Github, GPT',
#  'C#, C++, Visual Studio, Linux',
#  'C, C#, C++, OpenCV, Python, Halcon, Mil',
#  'AWS, Azure, Docker, GCP, kubernetes, NoSQL, Python, RDBMS, Scala, Spark',
#  'C++, Python, Pytorch, Tensorflow',
#  'Pytorch, Tensorflow',
#  'AWS, Azure, GCP, kubernetes, Linux',
#  'C#, C++, OpenCV, Python, R, Rust',
#  'Flutter, OpenCV, Python, Scipy, Tensorflow, Nginx, Numpy, fast-api, tkinter&PyQt',
#  'C++, Git, JAVA, Jira, Jquery, NoSQL, Pytorch, RDBMS, React, Spring Boot, Tensorflow, Vue',
#  'C#, C++, GoLang, Python, Ai, 머신러닝, 딥러닝',
#  'ArcGIS, CSS, HTML, JAVA, Javascript, Python, QGIS, PowerPoint, OA, 컴퓨터활용능력',
#  'Python, Pytorch, Tensorflow',
#  'C, C++, OpenCV',
#  'Hadoop, SQL, BigQuery, DBMS, JSON, 정보처리기사 자격',
#  'Python, Pytorch, Tensorflow, Scikit-Learn',
#  'API, AWS, Docker, Git, JAVA, JPA, MariaDB, MongoDB, MSA',
#  'API, AWS, Docker, Git, JAVA, JPA, MariaDB, MongoDB, MSA',
#  'JAVA, Matlab, Python, SQL',
#  'Python, Pytorch, Tensorflow, Lightning',
#  'C++, Python, Pytorch, Tensorflow, Tableau',
#  'AWS, Docker, Spring Boot, Notion, GitHub, 머신러닝, React',
#  'CSS, Django, Flask, HTML, PostgreSQL, Python, Fastapi, LLM',
#  'Azure, GCP, Javascript, PostgreSQL, Python, AWS EKS, BigQuery, Bitbucket',
#  'C++, OpenCV, Python, DL',
#  'Ajax, C, C#, C++, HTML, JSP, Python, SQL, Tensorflow',
#  'C++, Python',
#  'C, C#, C++, JAVA, Python, C++Builder',
#  'Keras, Python, Pytorch, Tensorflow, NAS, network compression',
#  'Hadoop, Kafka, NoSQL, Python, R, Spark, Nifi, MML, 생성 AI',
#  'Python, R',
#  'Python, Fortran',
#  'C#, C++, 영어회화, 1종보통운전면허, 2종보통운전면허, 운전면허, 컴퓨터활용능력',
#  'C, C++, 임베디드리눅스, Linux Application, bsp kernel',
#  'JAVA, Node',
#  'Python, Window, Linux',
#  'C#, C++, MFC, OpenCV, Qt, Halcon, Mil',
#  'C, C++, Pytorch',
#  'Javascript, React, TypeScript, Webpack, styled-components, vite, 인공지능, React Query, Ant Design',
#  'Hadoop, Keras, MongoDB, NoSQL, Python, Pytorch, SQL, Tensorflow, Apache Cassandra',
#  'Flutter, JAVA, Oracle, Python, React, TypeScript, Figma, Next',
#  'Keras, Python, Pytorch, Tensorflow, 라즈베리파이',
#  '일본어',
#  'Bootstrap, CSS3, Git, HTML, JAVA, Javascript, Jquery, JSP, MySQL, Pandas, Python, React, Servlet, Spring, ERP, 무역영어, GitHub, Matplotlib, Numpy, 국제무역사 자격',
#  'AWS, Git, Hadoop, JAVA, MyBatis, MySQL, OracleDB, Python, Spring, Spring Boot',
#  'Python, UI, UX, 기업 교육, 디지털 교육',
#  'Android, C#, HMI, JPA, OpenCV, Spring, SQL, ARM, AVR, JSTL, JWT, PLC, JUnit, IoT, 임베디드 시스템, 웹서버, alot, 인텔엣지',
#  'Ajax, CSS, HMI, HTML, JAVA, Javascript, JSP, MySQL, Oracle, SQL, 어셈블리',
#  'Jira, Figma, Amplitude, AppsFlyer, GTM, GA, powerBI',
#  'C, C++',
#  'C#, C++, OpenCV, Python',
#  '의사소통, 문제해결',
#  'Python',
#  'Ai, 챗봇, 데이터 전처리, 프롬프트 엔지니어',
#  'Excel, OA',
#  '',
#  'JAVA, 디버깅',
#  'Google Analytics, JAVA, Python, Spring, RPA',
#  'RPA, LowCode, Chat GPT4, outsystems',
#  '일본어, JLPT, JPT',
#  'Excel, 구글 스프레드시트',
#  'JAVA, Javascript, Python, React, RestAPI, Cloud, GUI, 백엔드, 프론트엔드, 챗봇',
#  'NoSQL, Python, Pytorch, Tensorflow, Cloud, NLU, NLP, LLM, Langchain, LlamaIndex']

# %%
# "'", "," 삭제

skill_list = apply_500_DF['스킬'][~apply_500_DF['스킬'].isna()].to_list()

with open ("skill_final_text.txt","w") as f:
	
	for skill in skill_list:
		f.write(clean_string(skill))

    # skill_list[idx] = skill.replace(",","").replace("'","")

# %%
utility_list = apply_500_DF['핵심역량'][~apply_500_DF['핵심역량'].isna()].to_list()

with open ("utility_final_text.txt","w") as f:
	
	for utility in utility_list:
		f.write(clean_string(utility) + ' ')

# %%
## 스킬 워드클라우드

# -----------------------------------------------------------
# 영문 wordCloud 생성

# 한글 내용 삭제 - skill_final_text_2.txt
# -----------------------------------------------------------

from wordcloud import STOPWORDS
from wordcloud import WordCloud
import matplotlib.pyplot as plt

import numpy as np
from PIL import Image

# stopwords = set(STOPWORDS)
# stopwords.add("Python Pytorch")



text = open('skill_final_text_2.txt').read()


# 워드클라우드 출력 형태 이미지 마스크 설정
img_mask = np.array(Image.open('cloud.png'))


# 워드클라우드 분석 ----------------------------------------------------------
wc = WordCloud(width=400, height=400,
               background_color="darkgrey", max_font_size=200,
               stopwords=STOPWORDS,
               repeat=False,
               colormap='seismic', mask=img_mask).generate(text)

# # 딕셔너리 형태로 할당해야만!!
# cloud = wc.generate_from_frequencies(dict(tags))

# words_: 객체의 비율 정보가 담긴 딕셔너리 반환
print(wc.words_)

# 워드클라우드 결과 이미지 생성
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(wc)
plt.show()
# Out:
# {'Python': 1.0, 'Python Pytorch': 0.6986301369863014, 'C C': 0.5616438356164384, 'C': 0.4520547945205479, 'Pytorch Tensorflow': 0.3835616438356164, 'JAVA': 0.3424657534246575, 'Tensorflow': 0.3424657534246575, 'Git': 0.3150684931506849, 'SQL': 0.3013698630136986, 'OpenCV': 0.3013698630136986, 'Spring': 0.2465753424657534, 'MySQL': 0.2328767123287671, 'AWS': 0.2054794520547945, 'Linux': 0.2054794520547945, 'Docker': 0.1917808219178082, 'JAVA Javascript': 0.1780821917808219, 'MariaDB': 0.1643835616438356, 'kubernetes': 0.1506849315068493, 'React': 0.1506849315068493, 'Javascript': 0.136986301369863, 'NoSQL': 0.136986301369863, 'Keras': 0.136986301369863, 'PostgreSQL': 0.1232876712328767, 'DL': 0.1232876712328767, 'Spark': 0.1232876712328767, 'Ai': 0.1232876712328767, 'Oracle': 0.1095890410958904, 'TensorflowC': 0.1095890410958904, 'GitHub': 0.1095890410958904, 'Kafka': 0.0958904109589041, 'MongoDB': 0.0958904109589041, 'MFC': 0.0958904109589041, 'Matlab': 0.0958904109589041, 'CNN': 0.0958904109589041, 'HTML JAVA': 0.0958904109589041, 'Hadoop': 0.0821917808219178, 'GCP': 0.0821917808219178, 'API': 0.0821917808219178, 'RestAPI': 0.0821917808219178, 'JSP': 0.0821917808219178, 'PythonC': 0.0821917808219178, 'CUDA': 0.0821917808219178, 'RDBMS': 0.0821917808219178, 'Django': 0.0821917808219178, 'Flask': 0.0821917808219178, 'Azure': 0.0684931506849315, 'Window': 0.0684931506849315, 'VIsualC': 0.0684931506849315, 'DBMS': 0.0684931506849315, 'Scikit': 0.0684931506849315, 'TensorflowPython': 0.0684931506849315, 'Pandas': 0.0684931506849315, 'ERP': 0.0547945205479452, 'Scala': 0.0547945205479452, 'HTML': 0.0547945205479452, 'NLP': 0.0547945205479452, 'LLM': 0.0547945205479452, 'Microsoft': 0.0547945205479452, 'VISION': 0.0547945205479452, 'TypeScript': 0.0547945205479452, 'Scipy': 0.0547945205479452, 'WPF': 0.0547945205479452, 'CSS': 0.0547945205479452, 'Halcon': 0.0547945205479452, 'ml': 0.0547945205479452, 'mlC': 0.0547945205479452, 'Ubuntu': 0.0547945205479452, 'JPA': 0.0547945205479452, 'Jira': 0.0547945205479452, 'Apache': 0.0547945205479452, 'NLP LLM': 0.0547945205479452, 'Swift': 0.0410958904109589, 'OCR': 0.0410958904109589, 'Qt': 0.0410958904109589, 'Verilog': 0.0410958904109589, 'Excel': 0.0410958904109589, 'SQLC': 0.0410958904109589, 'Matplotlib': 0.0410958904109589, 'Airflow': 0.0410958904109589, 'BigQuery': 0.0410958904109589, 'JSON': 0.0410958904109589, 'Boot': 0.0410958904109589, 'Figma': 0.0410958904109589, 'NLU': 0.0410958904109589, 'HMI': 0.0410958904109589, 'Jquery': 0.0410958904109589, 'Fastapi': 0.0410958904109589, 'Cloud': 0.0410958904109589, 'LinuxC': 0.0410958904109589, 'BSP': 0.0273972602739726, 'MCU': 0.0273972602739726, 'Kotlin': 0.0273972602739726, 'OpenGL': 0.0273972602739726, 'PHP': 0.0273972602739726, 'iOS': 0.0273972602739726, 'MSSQL': 0.0273972602739726, 'Restful': 0.0273972602739726, 'Flutter': 0.0273972602739726, 'RAGC': 0.0273972602739726, 'OpenCVC': 0.0273972602739726, 'DSP': 0.0273972602739726, 'Office': 0.0273972602739726, 'UVM': 0.0273972602739726, 'NodeJAVA': 0.0273972602739726, 'SAP': 0.0273972602739726, 'COMPUTER': 0.0273972602739726, 'Machine': 0.0273972602739726, 'ROS': 0.0273972602739726, 'Unix': 0.0273972602739726, 'Langchain': 0.0273972602739726, 'PythonPytorch': 0.0273972602739726, 'PythonJAVA': 0.0273972602739726, 'Logstash': 0.0273972602739726, 'LinuxPython': 0.0273972602739726, 'TensorflowAWS': 0.0273972602739726, 'TOEIC': 0.0273972602739726, 'Directx': 0.0273972602739726, 'TensorflowDocker': 0.0273972602739726, 'NLPAWS': 0.0273972602739726, 'CSS3': 0.0273972602739726, 'HTML5': 0.0273972602739726, 'VueAWS': 0.0273972602739726, 'MyBatis': 0.0273972602739726, 'PowerPoint': 0.0273972602739726, 'Notion': 0.0273972602739726, 'liama': 0.0273972602739726, 'PytorchPython': 0.0273972602739726, 'AiPython': 0.0273972602739726, 'SQLPython': 0.0273972602739726, 'algorithm': 0.0273972602739726, 'TensorflowHadoop': 0.0273972602739726, 'Shell': 0.0273972602739726, 'VueC': 0.0273972602739726, 'ETL': 0.027 ...

# %%
# 핵심역량 워드클라우드

# -----------------------------------------------------------
# 단어 분석 및 wordCloud 생성
# -----------------------------------------------------------

from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import platform

import numpy as np
from PIL import Image

okt = Okt() # Open Korean Text 객체 생성

text = open('utility_final_text.txt', encoding='utf-8').read()


# okt() 함수로 형태소 분석
sentences_tag = []
sentences_tag = okt.pos(text)

# tag가 명사 or 형용사인 단어들만 할당
noun_list = []
for word, tag in sentences_tag:
    if tag in ['Noun']:
        noun_list.append(word)

print(noun_list)

# 가장 많이 나온 단어 TOP 50 
counts = Counter(noun_list)
tags = counts.most_common(20)           # -> Counter(리스트) --> 리스트 항목의 각 개수를 Dict 반환
print(tags)                             # -> most_common(n) -->  빈도 수가 높은 상위 n개 반환        

stopwords= '심'

# tags.pop(stopwords)
tags.pop(4)

print(tags)

# 한글 분석 위한 font 한글로 지정
if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'


# 워드클라우드 출력 형태 이미지 마스크 설정
img_mask = np.array(Image.open('balloon.png'))

# 워드클라우드 분석 ----------------------------------------------------------
wc = WordCloud(font_path=path, width=400, height=400,
               background_color="gainsboro", max_font_size=200,
               repeat=True,
               colormap='BrBG', mask=img_mask)

# 딕셔너리 형태로 할당해야만!!
cloud = wc.generate_from_frequencies(dict(tags))

# 워드클라우드 결과 이미지 생성
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['계획성', '성실', '성실', '성취', '지향성', '계획성', '계획성', '성취', '지향성', '계획성', '성취', '지향성', '계획성', '성실', '계획성', '성취', '지향성', '계획성', '성실', '계획성', '성실', '계획성', '성취', '지향성', '창의성', '성장', '지향성', '성실', '협동', '심', '계획성', '성실', '적응', '창의성', '협동', '심', '계획성', '성실', '협동', '심', '메타', '성취', '지향성', '성실', '협동', '심', '계획성', '성실', '성실', '성취', '지향성', '스트레스', '관리', '성장', '지향성', '계획성', '윤리', '의식', '자존감', '적응', '창의성', '협동', '심', '계획성', '성취', '지향성', '성취', '지향성', '메타', '성실', '창의성', '계획성', '성실', '계획성', '성실', '성실', '윤리', '의식', '협동', '심', '성장', '지향성', '성취', '지향성', '계획성', '성실', '협동', '심', '적응', '창의성', '창의성', '협동', '심', '성장', '지향성', '성실', '자존감', '적응', '성실', '성취', '지향성', '협동', '심', '성장', '지향성', '적응', '협동', '심', '계획성', '성장', '지향성', '성실', '성취', '지향성', '성장', '지향성', '성실', '성취', '지향성', '계획성', '창의성', '성장', '지향성', '협동', '심', '적응', '성실', '성취', '지향성', '창의성', '협동', '심', '성장', '지향성', '계획성', '메타', '스트레스', '관리', '윤리', '의식', '자존감', '적응', '스트레스', '관리', '적응', '성장', '지향성', '성실', '창의성', '협동', '심', '계획성', '성실', '성취', '지향성', '성실', '윤리', '의식', '창의성', '성실', '창의성', '협동', '심', '성실', '성장', '지향성', '성취', '지향성', '협동', '심', '성장', '지향성', '성실', '계획성', '성실', '창의성', '성장', '지향성', '스트레스', '관리', '윤리', '의식', '성취', '지향성', '계획성', '성실', '창의성', '협동', '심', '메타', '성장', '지향성', '성취', '지향성', '스트레스', '관리', '성장', '지향성', '성실', '성취', '지향성', '성실', '창의성', '협동', '심', '성취', '지향성', '성장', '지향성', '계획성', '성실', '창의성', '협동', '심', '성취', '지향성', '계획성', '적응', '성장', '지향성', '창의성', '협동', '심', '성실', '스트레스', '관리', '윤리', '의식', '창의성', '협동', '심', '성장', '지향성', '적응', '성실', '성취', '지향성', '성장', '지향성', '계획성', '적응', '성실', '성장', '지향성', '성실', '성장', '지향성', '성취', '지향성', '창의성', '협동', '심', '성실', '적응', '계획성', '스트레스', '관리', '성취', '지향성', '창의성', '성장', '지향성', '성실', '창의성', '협동', '심', '성취', '지향성', '적응', '계획성', '윤리', '의식', '창의성', '협동', '심', '적응', '스트레스', '관리', '계획성', '성실', '성취', '지향성', '적응', '창의성', '성장', '지향성', '성실', '적응', '협동', '심', '계획성', '성실', '스트레스', '관리', '적응', '창의성', '성취', '지향성', '메타', '성실', '적응', '성실', '성장', '지향성', '계획성', '적응', '협동', '심', '성실', '협동', '심', '성장', '지향성', '적응', '성실', '협동', '심', '성장', '지향성', '계획성', '성실', '적응', '성장', '지향성', '협동', '심', '성장', '지향성', '메타', '창의성', '성장', '지향성', '성실', '협동', '심', '계획성', '성실', '협동', '심', '성장', '지향성', '계획성', '성실', '협동', '심', '성장', '지향성', '성취', '지향성', '적응', '협동', '심', '메타', '성실', '성장', '지향성', '성실', '성취', '지향성', '계획성', '성장', '지향성', '윤리', '의식', '성실', '성취', '지향성', '계획성', '성실', '협동', '심', '성장', '지향성', '성취', '지향성', '적응', '계획성', '적응', '협동', '심', '성장', '지향성', '창의성', '성실', '계획성', '협동', '심', '성장', '지향성', '성실', '성취', '지향성', '적응', '창의성', '계획성', '성실', '협동', '심', '성장', '지향성', '성취', '지향성', '적응', '계획성', '성실', '창의성', '협동', '심', '윤리', '의식', '창의성', '협동', '심', '성장', '지향성', '성실', '성취', '지향성', '스트레스', '관리', '성실', '적응', '협동', '심', '스트레스', '관리', '계획성', '성실', '메타', '자존감', '계획성', '성취', '지향성', '창의성', '성장', '지향성', '협동', '심', '적응', '성실', '성실', '창의성', '성장', '지향성', '계획성', '협동', '심', '성취', '지향성', '성실', '협동', '심', '성실', '윤리', '의식', '창의성', '협동', '심', '계획성', '성실', '윤리', '의식', '창의성', '협동', '심', '성실', '협동', '심', '계획성', '적응', '계획성', '성장', '지향성', '성실', '성취', '지향성', '적응', '창의성', '협동', '심', '협동', '심', '성취', '지향성', '창의성', '윤리', '의식', '적응', '성장', '지향성', '메타', '성취', '지향성', '스트레스', '관리', '성실', '적응', '협동', '심', '협동', '심', '성장', '지향성', '적응', '계획성', '성실', '창의성', '협동', '심', '성장', '지향성', '계획성', '성취', '지향성', '윤리', '의식', '자존감', '적응', '성실', '성취', '지향성', '성장', '지향성', '계획성', '계획성', '창의성', '성실', '성취', '지향성', '윤리', '의식', '계획성', '적응', '협동', '심', '계획성', '성실', '협동', '심', '스트레스', '관리', '자존감', '적응', '협동', '심', '메타', '성장', '지향성', '스트레스', '관리', '계획성', '성실', '계획성', '성장', '지향성', '협동', '심', '창의성', '성장', '지향성', '적응', '성취', '지향성', '창의성', '메타', '성장', '지향성', '계획성', '성실', '계획성', '성실', '성장', '지향성', '성취', '지향성', '협동', '심', '성실', '협동', '심', '성취', '지향성', '계획성', '성실', '협동', '심', '성장', '지향성', '계획성', '성실', '계획성', '성장', '지향성', '적응', '창의성', '계획성', '성실', '협동', '심', '윤리', '의식', '계획성', '성실', '창의성', '성실', '적응', '계획성', '계획성', '협동', '심', '성장', '지향성', '성실', '협동', '심', '성장', '지향성', '성실', '창의성', '협동', '심', '성장', '지향성', '성실', '창의성', '성장', '지향성', '성실', '성취', '지향성', '협동', '심', '성장', '지향성', '적응', '계획성', '성 ...
# [('지향성', 109), ('성실', 90), ('계획성', 72), ('협동', 66), ('심', 66), ('성장', 60), ('성취', 49), ('창의성', 44), ('적응', 44), ('윤리', 17), ('의식', 17), ('스트레스', 14), ('관리', 14), ('메타', 11), ('자존감', 6)]
# [('지향성', 109), ('성실', 90), ('계획성', 72), ('협동', 66), ('성장', 60), ('성취', 49), ('창의성', 44), ('적응', 44), ('윤리', 17), ('의식', 17), ('스트레스', 14), ('관리', 14), ('메타', 11), ('자존감', 6)]

# %% [markdown]
# ##### 경력 막대그래프

# %%
apply_500_DF.groupby('경력').count().reset_index()
# Out:
#                    경력  기업명   학력  핵심역량  스킬
# 0                  경력  156  143    40  82
# 1          경력 (10년이상)    6    6     1   5
# 2           경력 (1년이상)   18   18     3  17
# 3   경력 (1년이상) 직무 별 상이    1    1     0   1
# 4           경력 (2년이상)   34   34     6  24
# 5           경력 (3년이상)   91   91    18  59
# 6           경력 (4년이상)    7    7     2   3
# 7           경력 (5년이상)   48   48     9  31
# 8           경력 (6년이상)    5    5     1   4
# 9           경력 (7년이상)    6    6     2   6
# 10          경력 (8년이상)    5    5     3   4
# 11            경력 6년이상    1    1     0   1
# 12          경력 직무별 상이    2    2     2   1
# 13       경력 직무에 따라 상이    1    1     1   0
# 14                 신입  121  121    27  75

# %%
period_count = apply_500_DF.groupby('경력').count().reset_index()
period_count.loc[0:13]['기업명'].sum()
# Out:
# 381

# %%
xx = ['신입','경력']
yy = [121, period_count.loc[0:13]['기업명'].sum()]

colors = plt.cm.tab20.colors

plt.pie(yy, labels=xx, autopct='%.1f%%', startangle=90, counterclock=False,explode=[0.05, 0.05],
        colors=['lightsteelblue','darksalmon'], shadow=True)
plt.show()

# %%
apply_500_DF['경력'].value_counts()
# Out:
# 경력
# 경력                   156
# 신입                   121
# 경력 (3년이상)             91
# 경력 (5년이상)             48
# 경력 (2년이상)             34
# 경력 (1년이상)             18
# 경력 (4년이상)              7
# 경력 (10년이상)             6
# 경력 (7년이상)              6
# 경력 (6년이상)              5
# 경력 (8년이상)              5
# 경력 직무별 상이              2
# 경력 직무에 따라 상이           1
# 경력 (1년이상) 직무 별 상이      1
# 경력 6년이상                1
# Name: count, dtype: int64

# %%
apply_500_DF['경력'].value_counts().index
# Out:
# Index(['경력', '신입', '경력 (3년이상)', '경력 (5년이상)', '경력 (2년이상)', '경력 (1년이상)',
#        '경력 (4년이상)', '경력 (10년이상)', '경력 (7년이상)', '경력 (6년이상)', '경력 (8년이상)',
#        '경력 직무별 상이', '경력 직무에 따라 상이', '경력 (1년이상) 직무 별 상이', '경력 6년이상'],
#       dtype='object', name='경력')

# %%
apply_500_DF['경력'].value_counts().values
# Out:
# array([156, 121,  91,  48,  34,  18,   7,   6,   6,   5,   5,   2,   1,
#          1,   1], dtype=int64)

# %%
plt.figure(figsize=(10,6))

colors = plt.cm.tab20.colors

xxx = apply_500_DF['경력'].value_counts().index[2:8]
yyy = apply_500_DF['경력'].value_counts().values[2:8]

plt.bar(xxx,yyy, color=colors[1:-1:2])
plt.ylim(bottom=0,top=110)
plt.show()

# %%
apply_500_DF.groupby('학력').count().reset_index()
# Out:
#                       학력  기업명   경력  핵심역량   스킬
# 0                   고졸이상    3    3     0    2
# 1        고졸이상 (졸업예정자 가능)    1    1     1    1
# 2                   대졸이상  160  160    33  106
# 3     대졸이상 (ICT본부 고졸 이상)    1    1     1    0
# 4        대졸이상 (졸업예정자 가능)   41   41    13   38
# 5            대졸이상 직무별 상이    1    1     1    1
# 6              대학원(박사)이상    1    1     0    0
# 7              대학원(석사)이상   36   36     6   19
# 8   대학원(석사)이상 (졸업예정자 가능)   23   23     5    9
# 9                  초대졸이상   41   41    10   30
# 10      초대졸이상 (졸업예정자 가능)   13   13     9   11
# 11                  학력무관  167  167    36   95
# 12           학력무관 교육별 상이    1    1     0    1

# %%
apply_500_DF['학력'].value_counts().index
# Out:
# Index(['학력무관', '대졸이상', '초대졸이상', '대졸이상 (졸업예정자 가능)', '대학원(석사)이상',
#        '대학원(석사)이상 (졸업예정자 가능)', '초대졸이상 (졸업예정자 가능)', '고졸이상', '학력무관 교육별 상이',
#        '대졸이상 (ICT본부 고졸 이상)', '대졸이상 직무별 상이', '대학원(박사)이상', '고졸이상 (졸업예정자 가능)'],
#       dtype='object', name='학력')

# %%
plt.figure(figsize=(14,6))

colors = plt.cm.tab20.colors

xxx = apply_500_DF['학력'].value_counts().index[0:7]
yyy = apply_500_DF['학력'].value_counts().values[0:7]

bar1=plt.bar(xxx,yyy, color=colors[1:-1:2])

plt.bar_label(bar1, fmt ='{:,.0f}건', label_type='edge', padding=6, fontsize=12)

plt.xticks(rotation=45)
plt.ylim(bottom=0,top=190)
plt.show()

# %%
exceptlist = []
successlist = []
try:
	

	successlist.append(require[idx])

except Exception as e:
    print('실패', require[idx])
    exceptlist.append(require[idx])

# %%
require[0]

# %%
for idx in range(len(require)):
	
	print(idx+1)
	columns = ['경력','학력','핵심역량', '스킬']
	tmp_list = [''] * len(columns)
	idx_list=[]

	datass = require[idx]
	print(datass)

	# 경력 추가
	point_1 = datass.index('경력',0,len(datass))
	# 학력 있을 시
	if '학력' in datass:
		point_2 = datass.index('학력')
		tmp_list[0] = datass[point_1+1:point_2]


	# 학력 추가
	if '학력' in datass:
		point_2 = datass.index('학력')
		tmp_list[1] = datass[point_2+1]

	# 핵심역량 추가
	if '핵심역량' in datass:
		point_3 = datass.index('핵심역량')
		tmp_list[2] = datass[point_3+1]

	# 스킬 추가
	if '스킬' in datass:
		point_4 = datass.index('스킬')
		tmp_list[3] = datass[point_4+1]

	print(tmp_list)
	
	tot_tmp_list.append(tmp_list)

# print(tot_tmp_list[:10])

# %%
for idx in range(len(require)):
print(idx+1)
	tmp_list = [''] * len(columns)
	idx_list=[]

	datass = require[idx]

	point_1 = datass.find(columns[0])	# 경력	시작 인덱스			# 없으면 -1 반환
	point_2 = datass.find(columns[1])	# 학력	시작 인덱스
	point_3 = datass.find(columns[2])	# 핵심역량 시작 인덱스
	point_4 = datass.find(columns[3])	# 스킬 	시작 인덱스

	print(point_1,point_2, point_3, point_4)

	# 경력 추가
	tmp_list[0] = datass[point_1+3:point_2].strip()
	print(tmp_list)
	
	# 학력
	if (point_2 != -1) and (point_3 !=-1):
		tmp_list[1] = datass[point_2+3:point_3].strip()

	if (point_2 != -1) and (point_3 ==-1) and (point_4 !=-1):
		tmp_list[1] = datass[point_2+3:point_4].strip()

	if (point_2 != -1) and (point_3 ==-1) and (point_4 ==-1):
		tmp_list[1] = datass[point_2+3:].strip()
	

	# 핵심역량
	if ((point_3 != -1) and (point_4 !=-1)) and (point_3*point_4 > 0):
		tmp_list[2] = datass[point_3+5:point_4]

	# 스킬
	if point_4 != -1:
		tmp_list[3] = datass[point_4+3]
	
	tot_tmp_list.append(tmp_list)

print(tot_tmp_list[:10])
